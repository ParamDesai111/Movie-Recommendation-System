# %% [markdown]
# # Ingest the Cleaned Plot into table

# %%
import pandas as pd
import re
import nltk
import pyodbc
import sqlalchemy
from sqlalchemy import create_engine

# nltk resources are download
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\84146\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\84146\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Connection to the Database

# %%
import configparser

def read_config():
    config = configparser.ConfigParser()
    config.read('config.ini')
    return {
        'serveradminlogin': config['SQL']['serveradminlogin'],
        'serveradminpassword': config['SQL']['serveradminpassword'],
        'database': config['SQL']['database'],
        'servername': config['SQL']['servername']
    }


serveradminlogin = read_config()['serveradminlogin']
serveradminpassword = read_config()['serveradminpassword']
database = read_config()['database']
servername = read_config()['servername']

# %% [markdown]
# ## Ingesting the data into the table in SQL

# %%
file_path = '../cleaned_movies1.csv'
df = pd.read_csv(file_path)

df.head()
# Out:
#    imdbID                        title  year     rating runtime  \
# 0       1                   Carmencita  1894  NOT RATED   1 min
# 1     230                   Cinderella  1899        NaN   6 min
# 2     399       Jack and the Beanstalk  1902        NaN  10 min
# 3     417           A Trip to the Moon  1902       TV-G  13 min
# 4     447  Life of an American Fireman  1903  NOT RATED   6 min
#
#                        genre    released                            director  \
# 0         Documentary, Short         NaN                William K.L. Dickson
# 1               Drama, Short  1899-12-25                      Georges M�li�s
# 2             Short, Fantasy  1902-07-15  George S. Fleming, Edwin S. Porter
# 3  Short, Adventure, Fantasy  1902-10-04                      Georges M�li�s
# 4              Short, Action  1903-01-01  George S. Fleming, Edwin S. Porter
#
#                      writer                                             cast  \
# 0                       NaN                                       Carmencita
# 1  Charles Perrault (story)  Barral, Bleuette Bernon, Carmely, Jeanne d'Alcy
# 2                       NaN                                     Thomas White
# 3                       NaN          Fran�ois Lallement, Jules-Eug�ne Legris
# 4                       NaN     Vivian Vaughan, Arthur White, James H. White
#
#    ...  imdbRating  imdbVotes  \
# 0  ...         5.9     1032.0
# 1  ...         6.6      586.0
# 2  ...         6.2      442.0
# 3  ...         8.2    23904.0
# 4  ...         6.4     1158.0
#
#                                               poster  \
# 0  https://m.media-amazon.com/images/M/MV5BMjAzND...
# 1  https://m.media-amazon.com/images/M/MV5BMTgwMD...
# 2  https://m.media-amazon.com/images/M/MV5BMjAzNT...
# 3  https://m.media-amazon.com/images/M/MV5BMTQzMD...
# 4  https://m.media-amazon.com/images/M/MV5BMjAzNT...
#
#                                                 plot  \
# 0  Performing on what looks like a small wooden s...
# 1  A fairy godmother magically turns Cinderella's...
# 2  Porter's sequential continuity editing links s...
# 3  A group of astronomers go on an expedition to ...
# 4  Porter's sequential continuity editing links s...
#
#                                             fullplot language country awards  \
# 0  Performing on what looks like a small wooden s...      NaN     USA    NaN
# 1  A fairy godmother magically turns Cinderella's...      NaN  France    NaN
# 2  Porter's sequential continuity editing links s...  English     USA    NaN
# 3  A group of men travel to the moon by being sho...      NaN  France    NaN
# 4  Porter's sequential continuity editing links s...  English     USA    NaN
#
#                      lastupdated   type
# 0  2015-08-26 00:03:45.040000000  movie
# 1  2015-08-29 00:20:56.217000000  movie
# 2  2015-08-29 00:25:25.360000000  movie
# 3  2015-09-01 00:16:55.443000000  movie
# 4  2015-08-29 00:26:36.093000000  movie
#
# [5 rows x 21 columns]

# %%
df['clean_plot'] = df['plot'].str.lower() #Convert to lower case

#Regex, numbers and spaces and puncuations

df['clean_plot'] = df['clean_plot'].apply(lambda x: re.sub('[^a-zA-Z]', ' ', x))
df['clean_plot'] = df['clean_plot'].apply(lambda x: re.sub('\s+', ' ', x))
df['clean_plot']

# tokenize the sentence

# Convert all entries in 'clean_plot' to strings (or handle NaNs differently if preferred)
# df['clean_plot'] = df['clean_plot'].astype(str)

# Now apply the tokenization
df['clean_plot'] = df['clean_plot'].apply(lambda x: nltk.word_tokenize(x))

df['clean_plot']
# Out:
# 0        [performing, on, what, looks, like, a, small, ...
# 1        [a, fairy, godmother, magically, turns, cinder...
# 2        [porter, s, sequential, continuity, editing, l...
# 3        [a, group, of, astronomers, go, on, an, expedi...
# 4        [porter, s, sequential, continuity, editing, l...
#                                ...
# 34143    [arianna, is, nineteen, years, old, and, still...
# 34144    [five, interlocking, tales, of, terror, follow...
# 34145    [a, squad, of, unsuspecting, cops, goes, throu...
# 34146    [on, a, desolate, island, suicidal, sheep, fra...
# 34147    [the, story, of, a, minibus, driver, and, a, f...
# Name: clean_plot, Length: 34148, dtype: object

# %%
# Remove all the stop words 
nltk.download('stopwords')
stop_words = nltk.corpus.stopwords.words('english')
plot = []
for sentence in df['clean_plot']:
    temp = []
    for word in sentence:
        if word not in stop_words and len(word) >= 3:
            temp.append(word)
    plot.append(temp)
plot
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\84146\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [['performing',
#   'looks',
#   'like',
#   'small',
#   'wooden',
#   'stage',
#   'wearing',
#   'dress',
#   'hoop',
#   'skirt',
#   'white',
#   'high',
#   'heeled',
#   'pumps',
#   'carmencita',
#   'dance',
#   'kicks',
#   'twirls',
#   'smile',
#   'always',
#   'face'],
#  ['fairy',
#   'godmother',
#   'magically',
#   'turns',
#   'cinderella',
#   'rags',
#   'beautiful',
#   'dress',
#   'pumpkin',
#   'coach',
#   'cinderella',
#   'goes',
#   'ball',
#   'meets',
#   'prince',
#   'remember',
#   'leave',
#   'magic',
#   'runs'],
#  ['porter',
#   'sequential',
#   'continuity',
#   'editing',
#   'links',
#   'several',
#   'shots',
#   'form',
#   'narrative',
#   'famous',
#   'fairy',
#   'tale',
#   'story',
#   'jack',
#   'magic',
#   'beanstalk',
#   'borrowing',
#   'cinematographic',
#   'methods'],
#  ['group', 'astronomers', 'expedition', 'moon'],
#  ['porter',
#   'sequential',
#   'continuity',
#   'editing',
#   'links',
#   'several',
#   'shots',
#   'form',
#   'narrative',
#   'firemen',
#   'responding',
#   'house',
#   'fire',
#   'leave',
#   'station',
#   'horse',
#   'drawn',
#   'pumper',
#   'arrive'],
#  ['group',
#   'bandits',
#   'stage',
#   'brazen',
#   'train',
#   'hold',
#   'find',
#   'determined',
#   'posse',
#   'hot',
#   'heels'],
#  ['royal',
#   'court',
#   'prince',
#   'presenting',
#   'princess',
#   'pledged',
#   'marry',
#   'witch',
#   'suddenly',
#   'appears',
#   'though',
#   'driven',
#   'witch',
#   'soon',
#   'returns',
#   'summons',
#   'servants'],
#  ['using',
#   'every',
#   'known',
#   'means',
#   'transportation',
#   'several',
#   'savants',
#   'geographic',
#   'society',
#   'undertake',
#   'journey',
#   'alps',
#   'sun',
#   'finishes',
#   'sea'],
#  ['young',
#   'boy',
#   'opressed',
#   'mother',
#   'goes',
#   'outing',
#   'country',
#   'social',
#   'welfare',
#   'group',
#   'dares',
#   'dream',
#   'land',
#   'cares',
#   'ordinary',
#   'life',
#   'fade'],
#  ['two',
#   'travellers',
#   'tormented',
#   'satan',
#   'inn',
#   'inn',
#   'eventuly',
#   'experience',
#   'buggy',
#   'ride',
#   'heavens',
#   'courtesy',
#   'devil',
#   'takes',
#   'one',
#   'hell',
#   'roasts'],
#  ['caring',
#   'sick',
#   'daughter',
#   'doctor',
#   'called',
#   'away',
#   'sickbed',
#   'neighbor',
#   'finds',
#   'neighbor',
#   'gravely',
#   'ill',
#   'ignores',
#   'wife',
#   'pleas',
#   'come',
#   'home',
#   'care',
#   'daughter',
#   'taken',
#   'turn',
#   'worse'],
#  ['frankenstein',
#   'young',
#   'medical',
#   'student',
#   'trying',
#   'create',
#   'perfect',
#   'human',
#   'instead',
#   'creates',
#   'misshapen',
#   'monster',
#   'made',
#   'ill',
#   'done',
#   'frankenstein',
#   'comforted',
#   'fianc'],
#  ['cartoon',
#   'figures',
#   'announce',
#   'via',
#   'comic',
#   'strip',
#   'balloons',
#   'move',
#   'move',
#   'wildly',
#   'exaggerated',
#   'style'],
#  ['scientists',
#   'world',
#   'meeting',
#   'discuss',
#   'best',
#   'way',
#   'reach',
#   'north',
#   'pole',
#   'professor',
#   'maboul',
#   'demonstrates',
#   'innovative',
#   'equipment',
#   'designed'],
#  ['loosely',
#   'adapted',
#   'dante',
#   'divine',
#   'comedy',
#   'inspired',
#   'illustrations',
#   'gustav',
#   'dor',
#   'original',
#   'silent',
#   'film',
#   'restored',
#   'new',
#   'score',
#   'tangerine',
#   'dream'],
#  ['young',
#   'wife',
#   'musician',
#   'husband',
#   'live',
#   'poverty',
#   'new',
#   'york',
#   'city',
#   'tenement',
#   'husband',
#   'job',
#   'requires',
#   'away',
#   'number',
#   'days',
#   'return',
#   'robbed'],
#  ['mrs',
#   'harding',
#   'dies',
#   'leaves',
#   'mysterious',
#   'letter',
#   'pastor',
#   'note',
#   'tells',
#   'cold',
#   'miserly',
#   'husband',
#   'worked',
#   'death',
#   'asks',
#   'pastor',
#   'administer',
#   'small',
#   'trust'],
#  ['richard',
#   'gloucester',
#   'uses',
#   'manipulation',
#   'murder',
#   'gain',
#   'english',
#   'throne'],
#  ['fant',
#   'mas',
#   'makes',
#   'emperor',
#   'crime',
#   'first',
#   'robbery',
#   'royal',
#   'palace',
#   'hotel',
#   'abducts',
#   'lord',
#   'beltham',
#   'fant',
#   'mas',
#   'fame',
#   'increases',
#   'actor',
#   'valgrand',
#   'creates'],
#  ['ingeborg',
#   'holm',
#   'husband',
#   'opens',
#   'grocery',
#   'store',
#   'life',
#   'sunny',
#   'side',
#   'three',
#   'children',
#   'husband',
#   'becomes',
#   'sick',
#   'dies',
#   'ingeborg',
#   'tries',
#   'keep',
#   'store'],
#  ['dramatization',
#   'methods',
#   'young',
#   'women',
#   'abducted',
#   'otherwise',
#   'procured',
#   'prostitution'],
#  ['louis',
#   'feuillade',
#   'hour',
#   'epic',
#   'follows',
#   'fant',
#   'mas',
#   'criminal',
#   'lord',
#   'paris',
#   'master',
#   'disguise',
#   'creeping',
#   'assassin',
#   'black',
#   'pursued',
#   'equally',
#   'resourceful',
#   'inspector',
#   'juve',
#   'journalist',
#   'jer',
#   'fandor'],
#  ['body',
#   'disappears',
#   'inside',
#   'prison',
#   'series',
#   'crimes',
#   'take',
#   'place',
#   'seemingly',
#   'dead',
#   'man',
#   'juve',
#   'presumed',
#   'dead',
#   'fandor',
#   'must',
#   'investigate',
#   'alone',
#   'fantomas',
#   'finally',
#   'brought',
#   'justice'],
#  ['poor',
#   'student',
#   'rescues',
#   'beautiful',
#   'countess',
#   'soon',
#   'becomes',
#   'obsessed',
#   'sorcerer',
#   'makes',
#   'deal',
#   'young',
#   'man',
#   'give',
#   'fabulous',
#   'wealth',
#   'anything',
#   'wants',
#   'sign'],
#  ['woman',
#   'aid',
#   'police',
#   'officer',
#   'sweetheart',
#   'endeavors',
#   'uncover',
#   'prostitution',
#   'ring',
#   'kidnapped',
#   'sister',
#   'philanthropist',
#   'secretly',
#   'runs'],
#  ['two', 'love', 'triangles', 'intersect', 'ancient', 'pompei'],
#  ['objected',
#   'date',
#   'sweetheart',
#   'uncle',
#   'young',
#   'man',
#   'turns',
#   'thoughts',
#   'murder'],
#  ['three',
#   'centuries',
#   'christus',
#   'young',
#   'cabiria',
#   'kidnapped',
#   'pirates',
#   'one',
#   'eruption',
#   'etna',
#   'sold',
#   'slave',
#   'carthage',
#   'going',
#   'sacrificed'],
#  ['based',
#   'fairy',
#   'tale',
#   'cinderella',
#   'mistreated',
#   'stepmother',
#   'stepsisters',
#   'able',
#   'royal',
#   'ball',
#   'help',
#   'fairy',
#   'godmother'],
#  ['inspector',
#   'juve',
#   'seems',
#   'unable',
#   'put',
#   'fant',
#   'mas',
#   'behind',
#   'bars',
#   'press',
#   'comes',
#   'idea',
#   'juve',
#   'must',
#   'fant',
#   'mas',
#   'juve',
#   'soon',
#   'jailed',
#   'attempt',
#   'ease',
#   'stress'],
#  ['fant',
#   'mas',
#   'arrested',
#   'jailed',
#   'brussels',
#   'inspector',
#   'juve',
#   'wants',
#   'arrested',
#   'sentenced',
#   'crimes',
#   'france',
#   'thus',
#   'juve',
#   'settles',
#   'fant',
#   'mas',
#   'escape'],
#  ['cartoonist',
#   'winsor',
#   'mccay',
#   'brings',
#   'dinosaurus',
#   'back',
#   'life',
#   'figure',
#   'latest',
#   'creation',
#   'gertie',
#   'dinosaur'],
#  ['charlie',
#   'partner',
#   'deliver',
#   'piano',
#   'prospect',
#   'repossess',
#   'one',
#   'prospect',
#   'confuse',
#   'addresses',
#   'difficulties',
#   'delivering',
#   'piano',
#   'mule',
#   'cart'],
#  ['charlie',
#   'meets',
#   'couple',
#   'agrees',
#   'care',
#   'man',
#   'crippled',
#   'uncle',
#   'couple',
#   'breaks',
#   'man',
#   'new',
#   'girl',
#   'drops',
#   'eggs',
#   'charlie',
#   'slips',
#   'trying',
#   'control'],
#  ['parallel',
#   'stories',
#   'modern',
#   'preacher',
#   'medieval',
#   'monk',
#   'gabriel',
#   'ascetic',
#   'killed',
#   'ignorant',
#   'mob',
#   'making',
#   'nude',
#   'statue',
#   'representing',
#   'truth',
#   'also',
#   'represented',
#   'ghostly',
#   'naked',
#   'girl',
#   'flits',
#   'throughout',
#   'film'],
#  ['original',
#   'advertising',
#   'film',
#   'describes',
#   'drama',
#   'primitive',
#   'life',
#   'shores',
#   'north',
#   'pacific'],
#  ['religious',
#   'woman',
#   'seeks',
#   'save',
#   'people',
#   'destruction',
#   'seducing',
#   'murdering',
#   'enemy',
#   'leader',
#   'plans',
#   'get',
#   'complicated',
#   'falls'],
#  ['charlie',
#   'pretends',
#   'dentist',
#   'though',
#   'assistant',
#   'patient',
#   'stop',
#   'laughing',
#   'anesthesia',
#   'charlie',
#   'knocks',
#   'club',
#   'sent',
#   'drug',
#   'store'],
#  ['work',
#   'swindler',
#   'takes',
#   'job',
#   'reporter',
#   'witnessing',
#   'car',
#   'cliff',
#   'grabs',
#   'rival',
#   'reporter',
#   'camera',
#   'races',
#   'newspaper',
#   'office',
#   'enter',
#   'photo'],
#  ['abused', 'woman', 'finds', 'love', 'arms', 'famous', 'novelist'],
#  ['young',
#   'pauline',
#   'left',
#   'lot',
#   'money',
#   'wealthy',
#   'uncle',
#   'dies',
#   'however',
#   'uncle',
#   'secretary',
#   'named',
#   'guardian',
#   'marries',
#   'time',
#   'officially',
#   'take'],
#  ['chivalrous',
#   'british',
#   'officer',
#   'takes',
#   'blame',
#   'cousin',
#   'embezzlement',
#   'journeys',
#   'american',
#   'west',
#   'start',
#   'new',
#   'life',
#   'cattle',
#   'ranch'],
#  ['charlie',
#   'talks',
#   'wealthy',
#   'farmer',
#   'daughter',
#   'tillie',
#   'eloping',
#   'taking',
#   'father',
#   'money',
#   'city',
#   'tillie',
#   'gets',
#   'drunk',
#   'lands',
#   'jail',
#   'charlie',
#   'runs',
#   'money'],
#  ['charlie',
#   'everything',
#   'efficient',
#   'job',
#   'janitor',
#   'edna',
#   'buys',
#   'fiance',
#   'cashier',
#   'birthday',
#   'present',
#   'charlie',
#   'thinks',
#   'charles',
#   'love',
#   'presents',
#   'rose'],
#  ['civil',
#   'war',
#   'divides',
#   'friends',
#   'destroys',
#   'families',
#   'nothing',
#   'compared',
#   'anarchy',
#   'black',
#   'ruled',
#   'south',
#   'war'],
#  ['windy',
#   'bathing',
#   'resort',
#   'fighting',
#   'one',
#   'two',
#   'husbands',
#   'charlie',
#   'approaches',
#   'edna',
#   'two',
#   'husbands',
#   'fight',
#   'ice',
#   'cream',
#   'driven',
#   'away',
#   'husband',
#   'charlie',
#   'turns',
#   'wife'],
#  ['walking',
#   'along',
#   'bulldog',
#   'charlie',
#   'finds',
#   'good',
#   'luck',
#   'horseshoe',
#   'passes',
#   'training',
#   'camp',
#   'advertising',
#   'boxing',
#   'partner',
#   'take',
#   'beating',
#   'watching',
#   'others',
#   'lose'],
#  ['venal',
#   'spoiled',
#   'stockbroker',
#   'wife',
#   'impulsively',
#   'embezzles',
#   'charity',
#   'chairs',
#   'desperately',
#   'turns',
#   'burmese',
#   'ivory',
#   'trader',
#   'replace',
#   'stolen',
#   'money'],
#  ['order',
#   'help',
#   'smuggler',
#   'kinsmen',
#   'sultry',
#   'gypsy',
#   'seduces',
#   'corrupts',
#   'officer',
#   'civil',
#   'guard',
#   'turning',
#   'traitor',
#   'murderer'],
#  ['confederate',
#   'soldier',
#   'frank',
#   'winslow',
#   'terrified',
#   'war',
#   'eventually',
#   'runs',
#   'away',
#   'battle',
#   'finds',
#   'behind',
#   'enemy',
#   'lines',
#   'vital',
#   'information',
#   'must',
#   'decide'],
#  ['married', 'diplomat', 'falls', 'hopelessly', 'spell', 'predatory', 'woman'],
#  ['parallel',
#   'stories',
#   'modern',
#   'preacher',
#   'medieval',
#   'monk',
#   'gabriel',
#   'ascetic',
#   'killed',
#   'ignorant',
#   'mob',
#   'making',
#   'nude',
#   'statue',
#   'representing',
#   'truth',
#   'also',
#   'represented',
#   'ghostly',
#   'naked',
#   'girl',
#   'flits',
#   'throughout',
#   'film'],
#  ['tramp',
#   'steals',
#   'girl',
#   'handbag',
#   'tries',
#   'pick',
#   'charlie',
#   'pocket',
#   'loses',
#   'cigarettes',
#   'matches',
#   'rescues',
#   'hot',
#   'dog',
#   'man',
#   'thug',
#   'takes',
#   'walking',
#   'stick'],
#  ['edna',
#   'father',
#   'wants',
#   'marry',
#   'wealthy',
#   'count',
#   'charlie',
#   'edna',
#   'true',
#   'love',
#   'impersonates',
#   'count',
#   'dinner',
#   'real',
#   'count',
#   'shows',
#   'charlie',
#   'thrown',
#   'later',
#   'charlie'],
#  ['visit',
#   'pub',
#   'charlie',
#   'ben',
#   'cause',
#   'ruckus',
#   'posh',
#   'restaurant',
#   'charlie',
#   'later',
#   'finds',
#   'compromising',
#   'position',
#   'hotel',
#   'head',
#   'waiter',
#   'wife'],
#  ['pest',
#   'tries',
#   'several',
#   'theatre',
#   'seats',
#   'winding',
#   'front',
#   'fight',
#   'conductor',
#   'thrown',
#   'lobby',
#   'pushes',
#   'fat',
#   'lady',
#   'fountain',
#   'returns',
#   'sit'],
#  ['years',
#   'old',
#   'owens',
#   'becomes',
#   'ragged',
#   'orphan',
#   'sainted',
#   'mother',
#   'dies',
#   'conways',
#   'next',
#   'door',
#   'neighbors',
#   'take',
#   'owen',
#   'constant',
#   'drinking',
#   'jim',
#   'soon',
#   'puts',
#   'owen'],
#  ['shipowner',
#   'intends',
#   'scuttle',
#   'ship',
#   'last',
#   'voyage',
#   'get',
#   'insurance',
#   'money',
#   'charlie',
#   'tramp',
#   'love',
#   'owner',
#   'daughter',
#   'grabbed',
#   'captain',
#   'promises',
#   'help'],
#  ['little', 'fellow', 'finds', 'girl', 'dreams', 'work', 'family', 'farm'],
#  ['intrepid',
#   'reporter',
#   'loyal',
#   'friend',
#   'battle',
#   'bizarre',
#   'secret',
#   'society',
#   'criminals',
#   'known',
#   'vampires'],
#  ['captain',
#   'nemo',
#   'built',
#   'fantastic',
#   'submarine',
#   'mission',
#   'revenge',
#   'traveled',
#   'leagues',
#   'search',
#   'charles',
#   'denver',
#   'man',
#   'caused',
#   'death',
#   'princess',
#   'daaker'],
#  ['charlie',
#   'overworked',
#   'labourer',
#   'film',
#   'studio',
#   'helps',
#   'young',
#   'woman',
#   'find',
#   'work',
#   'even',
#   'coworkers',
#   'strike',
#   'tyrannical',
#   'boss'],
#  ['christ', 'takes', 'form', 'pacifist', 'count', 'end', 'senseless', 'war'],
#  ['charlie',
#   'burns',
#   'count',
#   'trousers',
#   'ironing',
#   'fired',
#   'tailor',
#   'finds',
#   'invitation',
#   'dinner',
#   'miss',
#   'moneybags',
#   'goes',
#   'place',
#   'count',
#   'charlie',
#   'goes',
#   'kitchen'],
#  ['wynne',
#   'mortimer',
#   'pampered',
#   'society',
#   'girl',
#   'daughter',
#   'william',
#   'mortimer',
#   'prominent',
#   'business',
#   'man',
#   'chances',
#   'meet',
#   'david',
#   'white',
#   'young',
#   'artist',
#   'whose',
#   'fame',
#   'already',
#   'assured',
#   'art'],
#  ['beach',
#   'front',
#   'house',
#   'fatty',
#   'mabel',
#   'live',
#   'launched',
#   'sea',
#   'villains',
#   'fatty',
#   'mabel',
#   'arise',
#   'find',
#   'beds',
#   'floating',
#   'sea',
#   'water'],
#  ['man',
#   'wife',
#   'criminal',
#   'pasts',
#   'quit',
#   'crime',
#   'respectable',
#   'citizens',
#   'one',
#   'day',
#   'member',
#   'old',
#   'gang',
#   'shows',
#   'threatens',
#   'expose'],
#  ['outcast',
#   'named',
#   'dorman',
#   'encounters',
#   'young',
#   'woman',
#   'lost',
#   'woods',
#   'defends',
#   'danger',
#   'forest',
#   'sheriff',
#   'dunn'],
#  ['young',
#   'man',
#   'get',
#   'woman',
#   'loves',
#   'becomes',
#   'famous',
#   'manages',
#   'get',
#   'picture',
#   'newspapers',
#   'determines',
#   'let',
#   'nothing',
#   'stand',
#   'way',
#   'exactly'],
#  ['little',
#   'orphan',
#   'girl',
#   'believes',
#   'life',
#   'falling',
#   'apart',
#   'seems',
#   'everything',
#   'could',
#   'possibly',
#   'wrong',
#   'wrong',
#   'however',
#   'certain',
#   'things',
#   'happen',
#   'begin',
#   'make'],
#  ['twelve',
#   'part',
#   'serial',
#   'following',
#   'adventures',
#   'masked',
#   'vigilante',
#   'judex',
#   'fights',
#   'criminals',
#   'led',
#   'corrupt',
#   'banker',
#   'favrauxom'],
#  ['lear',
#   'old',
#   'man',
#   'blind',
#   'weaknesses',
#   'decides',
#   'divide',
#   'kingdom',
#   'among',
#   'three',
#   'daughters',
#   'according',
#   'recites',
#   'best',
#   'declaration',
#   'love',
#   'goneril',
#   'regan',
#   'pretend'],
#  ['story',
#   'poor',
#   'young',
#   'woman',
#   'separated',
#   'prejudice',
#   'husband',
#   'baby',
#   'interwoven',
#   'tales',
#   'intolerance',
#   'throughout',
#   'history'],
#  ['drunken',
#   'homeowner',
#   'difficult',
#   'time',
#   'getting',
#   'home',
#   'arriving',
#   'home',
#   'late',
#   'night'],
#  ['charlie',
#   'competes',
#   'fellow',
#   'shop',
#   'assistant',
#   'fired',
#   'pawnbroker',
#   'rehired',
#   'nearly',
#   'destroys',
#   'everything',
#   'shop',
#   'helps',
#   'capture',
#   'burglar',
#   'destroys',
#   'client',
#   'clock',
#   'examining',
#   'detail'],
#  ['charlie',
#   'released',
#   'prison',
#   'immediately',
#   'swindled',
#   'fake',
#   'parson',
#   'fellow',
#   'convict',
#   'convinces',
#   'charlie',
#   'help',
#   'burglarize',
#   'house',
#   'edna',
#   'house',
#   'owner',
#   'catches'],
#  ['causing',
#   'restaurant',
#   'chaos',
#   'work',
#   'bumbling',
#   'waiter',
#   'tears',
#   'local',
#   'roller',
#   'rink',
#   'skating'],
#  ['passing',
#   'hat',
#   'taking',
#   'donations',
#   'intended',
#   'german',
#   'street',
#   'musicians',
#   'charlie',
#   'heads',
#   'country',
#   'finds',
#   'rescues',
#   'girl',
#   'band',
#   'gypsies',
#   'girl',
#   'falls'],
#  ['little',
#   'tramp',
#   'escapes',
#   'prison',
#   'saves',
#   'girl',
#   'mother',
#   'drowning',
#   'creates',
#   'havoc',
#   'swank',
#   'party'],
#  ['roscoe',
#   'tries',
#   'dump',
#   'wife',
#   'enjoy',
#   'beach',
#   'attractions',
#   'buster',
#   'arrives',
#   'alice',
#   'taken',
#   'away',
#   'loses',
#   'roscoe',
#   'bathing',
#   'beauties',
#   'keystone',
#   'kops',
#   'abound'],
#  ['alcoholic',
#   'checks',
#   'health',
#   'spa',
#   'antics',
#   'promptly',
#   'throw',
#   'establishment',
#   'chaos'],
#  ['reformed',
#   'tramp',
#   'becomes',
#   'police',
#   'constable',
#   'must',
#   'fight',
#   'huge',
#   'thug',
#   'dominates',
#   'inner',
#   'city',
#   'street'],
#  ['charlie',
#   'immigrant',
#   'endures',
#   'challenging',
#   'voyage',
#   'gets',
#   'trouble',
#   'soon',
#   'arrives',
#   'america'],
#  ['roscoe',
#   'wife',
#   'mother',
#   'law',
#   'run',
#   'seaside',
#   'resort',
#   'buster',
#   'plays',
#   'gardener',
#   'puts',
#   'fire',
#   'started',
#   'roscoe',
#   'delivery',
#   'boy',
#   'fights',
#   'cook',
#   'john',
#   'cop'],
#  ['great', 'war', 'german', 'japanese', 'spies', 'face', 'united', 'states'],
#  ['terje',
#   'vigen',
#   'sailor',
#   'suffers',
#   'loss',
#   'family',
#   'cruelty',
#   'another',
#   'man',
#   'years',
#   'later',
#   'enemy',
#   'family',
#   'finds',
#   'dependent',
#   'terje',
#   'beneficence',
#   'terje',
#   'must'],
#  ['amarilly',
#   'comes',
#   'large',
#   'family',
#   'working',
#   'class',
#   'neighborhood',
#   'happy',
#   'family',
#   'boyfriend',
#   'terry',
#   'bartender',
#   'cafe',
#   'one',
#   'day',
#   'meets',
#   'gordon',
#   'sculptor'],
#  ['stranger',
#   'comes',
#   'work',
#   'widow',
#   'halla',
#   'farm',
#   'halla',
#   'stranger',
#   'fall',
#   'love',
#   'revealed',
#   'eyvind',
#   'escaped',
#   'thief',
#   'forced',
#   'crime',
#   'family',
#   'starvation'],
#  ['elk',
#   'head',
#   'hotel',
#   'bellhops',
#   'torment',
#   'lobby',
#   'guests',
#   'elevator',
#   'powered',
#   'stubborn',
#   'horse',
#   'sham',
#   'robbery',
#   'turns',
#   'real',
#   'one',
#   'chase'],
#  ['two',
#   'peasant',
#   'children',
#   'mytyl',
#   'tyltyl',
#   'led',
#   'berylune',
#   'fairy',
#   'search',
#   'blue',
#   'bird',
#   'happiness',
#   'berylune',
#   'gives',
#   'tyltyl',
#   'cap',
#   'diamond',
#   'setting',
#   'tyltyl',
#   'turns'],
#  ['tragic',
#   'story',
#   'jose',
#   'spanish',
#   'cavalryman',
#   'falls',
#   'spell',
#   'gypsy',
#   'girl',
#   'carmen',
#   'treats',
#   'love',
#   'contempt',
#   'leads',
#   'temptation',
#   'thus'],
#  ['little',
#   'tramp',
#   'dog',
#   'companion',
#   'struggle',
#   'survive',
#   'inner',
#   'city'],
#  ['mickey',
#   'orphan',
#   'brought',
#   'mining',
#   'settlement',
#   'sent',
#   'new',
#   'york',
#   'live',
#   'aunt'],
#  ['charles',
#   'murdock',
#   'neglects',
#   'fat',
#   'lazy',
#   'wife',
#   'favor',
#   'juliet',
#   'raeburn',
#   'juliet',
#   'name',
#   'involved',
#   'murder',
#   'marries',
#   'viola',
#   'takes',
#   'paris'],
#  ['charlie',
#   'boot',
#   'camp',
#   'private',
#   'dream',
#   'hero',
#   'goes',
#   'daring',
#   'mission',
#   'behind',
#   'enemy',
#   'lines'],
#  ['stella',
#   'maris',
#   'beautiful',
#   'crippled',
#   'girl',
#   'cared',
#   'rich',
#   'family',
#   'shield',
#   'harsh',
#   'realities',
#   'world',
#   'idea',
#   'cruel',
#   'things'],
#  ['john',
#   'trimble',
#   'embezzled',
#   'obtains',
#   'another',
#   'identity',
#   'mutilated',
#   'body',
#   'buried',
#   'place',
#   'later',
#   'arrested',
#   'murdering',
#   'trial',
#   'mother',
#   'dying'],
#  ['two',
#   'male',
#   'musicians',
#   'fall',
#   'love',
#   'blackmail',
#   'scandal',
#   'makes',
#   'affair',
#   'take',
#   'tragic',
#   'turn'],
#  ['american', 'heiress', 'seeks', 'hand', 'impoverished', 'german', 'prince'],
#  ['roscoe',
#   'buster',
#   'working',
#   'vaudeville',
#   'house',
#   'crew',
#   'attacks',
#   'strongman',
#   'bullying',
#   'assistant',
#   'man',
#   'goes',
#   'strike',
#   'crew',
#   'puts',
#   'show'],
#  ['austrian', 'officer', 'sets', 'seduce', 'neglected', 'young', 'wife'],
#  ['frail',
#   'waif',
#   'abused',
#   'brutal',
#   'boxer',
#   'father',
#   'london',
#   'seedy',
#   'limehouse',
#   'district',
#   'befriended',
#   'sensitive',
#   'chinese',
#   'immigrant',
#   'tragic',
#   'consequences'],
#  ['young',
#   'baseball',
#   'pitcher',
#   'bush',
#   'leagues',
#   'discovered',
#   'big',
#   'league',
#   'manager',
#   'given',
#   'chance',
#   'major',
#   'leagues',
#   'challenge'],
#  ['wealthy',
#   'jervis',
#   'pendleton',
#   'acts',
#   'benefactor',
#   'orphan',
#   'judy',
#   'abbott',
#   'anonymously',
#   'sponsoring',
#   'boarding',
#   'school',
#   'grows',
#   'finds',
#   'falling',
#   'love'],
#  ['father',
#   'takes',
#   'family',
#   'drive',
#   'falling',
#   'apart',
#   'model',
#   'ford',
#   'gets',
#   'trouble',
#   'traffic',
#   'spends',
#   'day',
#   'excursion',
#   'boat',
#   'boat',
#   'leave',
#   'charlie',
#   'rushes'],
#  ['leila',
#   'porter',
#   'comes',
#   'dislike',
#   'husband',
#   'james',
#   'glue',
#   'king',
#   'always',
#   'eating',
#   'onions',
#   'looking',
#   'sloppy',
#   'divorces',
#   'marries',
#   'two',
#   'timing',
#   'playboy',
#   'schuyler',
#   'van',
#   'sutphen',
#   'reformed',
#   'james',
#   'looks',
#   'pretty',
#   'good'],
#  ['roscoe',
#   'buster',
#   'operate',
#   'combination',
#   'garage',
#   'fire',
#   'station',
#   'first',
#   'half',
#   'destroy',
#   'car',
#   'left',
#   'clean',
#   'second',
#   'half',
#   'false',
#   'alarm',
#   'return',
#   'find',
#   'building',
#   'fire'],
#  ['penniless',
#   'young',
#   'man',
#   'tries',
#   'save',
#   'heiress',
#   'kidnappers',
#   'help',
#   'secure',
#   'inheritance'],
#  ['jailed',
#   'unjustly',
#   'murder',
#   'commit',
#   'young',
#   'man',
#   'uses',
#   'amazing',
#   'powers',
#   'escape',
#   'free',
#   'pursue',
#   'actual',
#   'killers',
#   'hold',
#   'fianc',
#   'captive'],
#  ['buddah',
#   'priest',
#   'wants',
#   'daughter',
#   'daimyo',
#   'become',
#   'priest',
#   'forbidden',
#   'garden',
#   'daimyo',
#   'thinks',
#   'europe',
#   'daughter',
#   'decide'],
#  ['three',
#   'scottish',
#   'officers',
#   'including',
#   'sir',
#   'archi',
#   'murder',
#   'sir',
#   'arne',
#   'household',
#   'coffin',
#   'filled',
#   'gold',
#   'survivor',
#   'elsalill',
#   'moves',
#   'relatives',
#   'marstrand'],
#  ['teenaged',
#   'tomboy',
#   'tired',
#   'bossed',
#   'around',
#   'strict',
#   'guardian',
#   'impersonates',
#   'man',
#   'fun',
#   'discovers',
#   'opposite',
#   'sex',
#   'easy',
#   'hoped'],
#  ['story',
#   'two',
#   'men',
#   'one',
#   'married',
#   'lover',
#   'wife',
#   'meet',
#   'trenches',
#   'first',
#   'world',
#   'war',
#   'tale',
#   'becomes',
#   'microcosm',
#   'horrors',
#   'war'],
#  ['caligari', 'somnambulist', 'cesare', 'deadly', 'predictions'],
#  ['lady',
#   'mary',
#   'lasenby',
#   'spoiled',
#   'maiden',
#   'always',
#   'gets',
#   'way',
#   'shipwrecked',
#   'butler',
#   'learns',
#   'qualities',
#   'really',
#   'admirable',
#   'person'],
#  ['kay',
#   'hoog',
#   'finds',
#   'message',
#   'indicates',
#   'incas',
#   'still',
#   'alive',
#   'secret',
#   'organisation',
#   'die',
#   'spinnen',
#   'wants',
#   'incas',
#   'gold'],
#  ['charlie',
#   'works',
#   'farm',
#   'late',
#   'night',
#   'gets',
#   'food',
#   'run',
#   'milking',
#   'cow',
#   'coffee',
#   'holding',
#   'chicken',
#   'frying',
#   'pan',
#   'get',
#   'fried',
#   'eggs',
#   'loves'],
#  ['susie',
#   'plain',
#   'young',
#   'country',
#   'girl',
#   'secretly',
#   'loves',
#   'neighbor',
#   'boy',
#   'william',
#   'believes',
#   'sacrifices',
#   'much',
#   'happiness',
#   'promote',
#   'ambitions',
#   'without'],
#  ['seeing',
#   'griffith',
#   'epic',
#   'intolerance',
#   'denmark',
#   'greatest',
#   'director',
#   'carl',
#   'theodor',
#   'dreyer',
#   'passion',
#   'joan',
#   'arc',
#   'vampyr',
#   'inspired',
#   'make',
#   'four',
#   'episode',
#   'historical'],
#  ['tragic',
#   'story',
#   'jose',
#   'spanish',
#   'cavalryman',
#   'falls',
#   'spell',
#   'gypsy',
#   'girl',
#   'carmen',
#   'treats',
#   'love',
#   'contempt',
#   'leads',
#   'temptation',
#   'thus'],
#  ['young',
#   'golfer',
#   'mugged',
#   'escaped',
#   'convict',
#   'finds',
#   'prison',
#   'foils',
#   'jailbreak'],
#  ['henry',
#   'jekyll',
#   'experiments',
#   'scientific',
#   'means',
#   'revealing',
#   'hidden',
#   'dark',
#   'side',
#   'man',
#   'releases',
#   'murderer',
#   'within'],
#  ['erotikon',
#   'surely',
#   'pushed',
#   'boundaries',
#   'acceptable',
#   'screen',
#   'irene',
#   'bored',
#   'wife',
#   'distracted',
#   'entomologist',
#   'pursues',
#   'womanizing',
#   'aviator',
#   'may',
#   'actually'],
#  ['century',
#   'prague',
#   'rabbi',
#   'creates',
#   'giant',
#   'creature',
#   'clay',
#   'called',
#   'golem',
#   'using',
#   'sorcery',
#   'brings',
#   'creature',
#   'life',
#   'order',
#   'protect',
#   'jews',
#   'prague',
#   'persecution'],
#  ['tipsy',
#   'doctor',
#   'encounters',
#   'patient',
#   'sleepwalking',
#   'building',
#   'ledge',
#   'high',
#   'street'],
#  ['small', 'town', 'tramp', 'befriends', 'runaway', 'boy'],
#  ['alice',
#   'cora',
#   'munro',
#   'attempt',
#   'find',
#   'father',
#   'british',
#   'officer',
#   'french',
#   'indian',
#   'war',
#   'set',
#   'upon',
#   'french',
#   'soldiers',
#   'cohorts',
#   'huron',
#   'tribesmen',
#   'led',
#   'evil'],
#  ['seemingly',
#   'idiotic',
#   'fop',
#   'really',
#   'courageous',
#   'vigilante',
#   'zorro',
#   'seeks',
#   'protect',
#   'oppressed'],
#  ['amusement',
#   'park',
#   'two',
#   'men',
#   'try',
#   'win',
#   'heart',
#   'young',
#   'lady',
#   'compete',
#   'attempting',
#   'find',
#   'runaway',
#   'dog',
#   'race',
#   'ask',
#   'mother',
#   'permission',
#   'take',
#   'hot',
#   'air',
#   'balloon'],
#  ['deformed',
#   'criminal',
#   'mastermind',
#   'plans',
#   'loot',
#   'city',
#   'san',
#   'francisco',
#   'well',
#   'revenge',
#   'doctor',
#   'mistakenly',
#   'amputated',
#   'legs'],
#  ['simple',
#   'minded',
#   'son',
#   'rich',
#   'financier',
#   'must',
#   'find',
#   'way',
#   'world'],
#  ['kay',
#   'hoog',
#   'wants',
#   'stop',
#   'organisation',
#   'die',
#   'spinnen',
#   'get',
#   'certain',
#   'diamond',
#   'give',
#   'owning',
#   'woman',
#   'crown',
#   'asia',
#   'man',
#   'owner',
#   'diamond'],
#  ['naive',
#   'country',
#   'girl',
#   'tricked',
#   'sham',
#   'marriage',
#   'wealthy',
#   'womanizer',
#   'must',
#   'rebuild',
#   'life',
#   'despite',
#   'taint',
#   'borne',
#   'child',
#   'wedlock'],
#  ['robert',
#   'beth',
#   'gordon',
#   'married',
#   'share',
#   'little',
#   'runs',
#   'sally',
#   'cabaret',
#   'gordons',
#   'soon',
#   'divorced',
#   'gets',
#   'bored',
#   'sally',
#   'superficiality',
#   'beth',
#   'strives'],
#  ['romantic',
#   'rivalry',
#   'among',
#   'members',
#   'secret',
#   'society',
#   'becomes',
#   'even',
#   'tenser',
#   'one',
#   'men',
#   'assigned',
#   'carry',
#   'assassination'],
#  ['socialite',
#   'anatol',
#   'spencer',
#   'seeks',
#   'better',
#   'relation',
#   'wife',
#   'sets',
#   'friend',
#   'youth',
#   'emilie',
#   'apartment',
#   'two',
#   'time',
#   'comforts',
#   'near'],
#  ['tarzan',
#   'spurns',
#   'love',
#   'queen',
#   'opar',
#   'trying',
#   'keep',
#   'bolshevik',
#   'rokoff',
#   'clayton',
#   'pretender',
#   'greystoke',
#   'estate',
#   'reaching',
#   'opar',
#   'attacked'],
#  ['charismatic',
#   'lieutenant',
#   'newly',
#   'assigned',
#   'remote',
#   'fort',
#   'captured',
#   'group',
#   'mountain',
#   'bandits',
#   'thus',
#   'setting',
#   'motion',
#   'madcap',
#   'farce',
#   'lubitsch',
#   'unrestrained'],
#  ['professor',
#   'dispenses',
#   'wisdom',
#   'ages',
#   'make',
#   'living',
#   'wage',
#   'sons',
#   'rich',
#   'powerful',
#   'students',
#   'lacking',
#   'motivation',
#   'next',
#   'door',
#   'neighbor'],
#  ['buster',
#   'family',
#   'voyage',
#   'homemade',
#   'boat',
#   'proves',
#   'one',
#   'disaster',
#   'another'],
#  ['courtesan',
#   'idealistic',
#   'young',
#   'man',
#   'fall',
#   'love',
#   'give',
#   'relationship',
#   'status',
#   'conscious',
#   'father',
#   'request'],
#  ['extended',
#   'family',
#   'split',
#   'france',
#   'germany',
#   'find',
#   'opposing',
#   'sides',
#   'battlefield',
#   'world',
#   'war'],
#  ['series',
#   'adventures',
#   'begins',
#   'accident',
#   'photographing',
#   'causes',
#   'buster',
#   'mistaken',
#   'dead',
#   'shot',
#   'dan',
#   'evil',
#   'badguy'],
#  ['bank',
#   'clerk',
#   'ends',
#   'seemingly',
#   'haunted',
#   'house',
#   'actually',
#   'thieves',
#   'hideout'],
#  ['drifter',
#   'amusement',
#   'park',
#   'finds',
#   'bodyguard',
#   'hit',
#   'man',
#   'man',
#   'targeted',
#   'criminal',
#   'gang'],
#  ['tramp',
#   'sneaks',
#   'upper',
#   'class',
#   'golf',
#   'resort',
#   'tramp',
#   'meets',
#   'rich',
#   'woman',
#   'argument',
#   'drunken',
#   'husband',
#   'complications',
#   'arise',
#   'mistakes',
#   'tramp',
#   'husband'],
#  ['tramp',
#   'cares',
#   'abandoned',
#   'child',
#   'events',
#   'put',
#   'relationship',
#   'jeopardy'],
#  ['new',
#   'year',
#   'eve',
#   'three',
#   'drunkards',
#   'evoke',
#   'legend',
#   'legend',
#   'tells',
#   'last',
#   'person',
#   'die',
#   'year',
#   'great',
#   'sinner',
#   'drive',
#   'whole',
#   'year',
#   'phantom'],
#  ['angela',
#   'maintains',
#   'coastal',
#   'lighthouse',
#   'italy',
#   'awaits',
#   'return',
#   'brothers',
#   'war',
#   'learns',
#   'casualties',
#   'takes',
#   'solace',
#   'arms',
#   'american',
#   'sailor'],
#  ['wlliam',
#   'demille',
#   'produced',
#   'directed',
#   'miss',
#   'lulu',
#   'bett',
#   'film',
#   'extraordinary',
#   'conviction',
#   'insight',
#   'often',
#   'custom',
#   'unmarried',
#   'women',
#   'lodge',
#   'family',
#   'thus',
#   'discover'],
#  ['hero',
#   'lloyd',
#   'infatuated',
#   'girl',
#   'next',
#   'office',
#   'order',
#   'drum',
#   'business',
#   'boss',
#   'osteopath',
#   'gets',
#   'actor',
#   'friend',
#   'pretend',
#   'injuries',
#   'doctor',
#   'cures'],
#  ['woman',
#   'fianc',
#   'disappears',
#   'death',
#   'gives',
#   'three',
#   'chances',
#   'save',
#   'fate'],
#  ['young',
#   'man',
#   'unaccustomed',
#   'children',
#   'must',
#   'accompany',
#   'young',
#   'girl',
#   'train',
#   'trip'],
#  ['buster',
#   'helps',
#   'native',
#   'american',
#   'tribe',
#   'save',
#   'land',
#   'greedy',
#   'oil',
#   'barons'],
#  ['two',
#   'orphaned',
#   'sisters',
#   'caught',
#   'turmoil',
#   'french',
#   'revolution',
#   'encountering',
#   'misery',
#   'love',
#   'along',
#   'way'],
#  ['waking',
#   'wacky',
#   'dream',
#   'theater',
#   'stage',
#   'hand',
#   'inadvertently',
#   'causes',
#   'havoc',
#   'everywhere',
#   'works'],
#  ['castle',
#   'vogeloed',
#   'aristocrats',
#   'awaiting',
#   'baroness',
#   'safferst',
#   'first',
#   'count',
#   'oetsch',
#   'invites',
#   'everyone',
#   'thinks',
#   'murdered',
#   'brother',
#   'baroness',
#   'safferstat',
#   'first'],
#  ['charming',
#   'arabian',
#   'sheik',
#   'becomes',
#   'infatuated',
#   'adventurous',
#   'modern',
#   'thinking',
#   'englishwoman',
#   'abducts',
#   'home',
#   'saharan',
#   'desert'],
#  ['young',
#   'gascon',
#   'artagnan',
#   'arrives',
#   'paris',
#   'heart',
#   'set',
#   'joining',
#   'king',
#   'musketeers',
#   'taken',
#   'wings',
#   'three',
#   'respected',
#   'feared',
#   'musketeers',
#   'porthos'],
#  ['three',
#   'thuggish',
#   'men',
#   'responsible',
#   'death',
#   'father',
#   'crippling',
#   'brother',
#   'young',
#   'david',
#   'must',
#   'choose',
#   'supporting',
#   'family',
#   'risking',
#   'life',
#   'exacting',
#   'vengeance'],
#  ['buster',
#   'keaton',
#   'shoes',
#   'horses',
#   'repairs',
#   'cars',
#   'mixed',
#   'results'],
#  ['toreador', 'familial', 'social', 'life', 'threatened', 'affair'],
#  ['young',
#   'woman',
#   'marries',
#   'older',
#   'millionaire',
#   'falls',
#   'love',
#   'handsome',
#   'nobleman',
#   'honeymoon'],
#  ['sincere',
#   'young',
#   'man',
#   'leaves',
#   'home',
#   'win',
#   'fortune',
#   'marry',
#   'home',
#   'town',
#   'sweetheart'],
#  ['arch',
#   'criminal',
#   'mabuse',
#   'sets',
#   'make',
#   'fortune',
#   'run',
#   'berlin',
#   'detective',
#   'wenk',
#   'sets',
#   'stop'],
#  ['country',
#   'doctor',
#   'jack',
#   'jackson',
#   'called',
#   'treat',
#   'sick',
#   'little',
#   'well',
#   'girl',
#   'making',
#   'saulsbourg',
#   'sanitarium',
#   'rich',
#   'years',
#   'unsuccessful',
#   'treatment'],
#  ['mistakenly',
#   'certified',
#   'electrical',
#   'engineer',
#   'buster',
#   'hired',
#   'wire',
#   'house'],
#  ['convict',
#   'hiding',
#   'chinatown',
#   'assumes',
#   'identity',
#   'cripple',
#   'track',
#   'businessman',
#   'framed',
#   'years',
#   'previously',
#   'discovers',
#   'daughter',
#   'fallen',
#   'love',
#   'businessman',
#   'son'],
#  ['con',
#   'artist',
#   'masquerades',
#   'russian',
#   'nobility',
#   'attempts',
#   'seduce',
#   'wife',
#   'american',
#   'diplomat'],
#  ['buster', 'plays', 'bumbling', 'villain', 'parody', 'melodrama'],
#  ['meek',
#   'young',
#   'man',
#   'must',
#   'find',
#   'courage',
#   'within',
#   'rogue',
#   'tramp',
#   'menaces',
#   'home',
#   'town'],
#  ['fictionalized',
#   'documentary',
#   'showing',
#   'evolution',
#   'witchcraft',
#   'pagan',
#   'roots',
#   'confusion',
#   'hysteria',
#   'modern',
#   'europe'],
#  ['man',
#   'frozen',
#   'arctic',
#   'ice',
#   'years',
#   'returns',
#   'civilization',
#   'find',
#   'lost',
#   'love'],
#  ['society',
#   'girl',
#   'thrill',
#   'seeker',
#   'lydia',
#   'causes',
#   'death',
#   'motorcycle',
#   'policeman',
#   'prosecuted',
#   'fianc',
#   'daniel',
#   'describes',
#   'lurid',
#   'detail',
#   'downfall',
#   'rome',
#   'prison',
#   'reforms',
#   'daniel',
#   'becomes',
#   'wasted',
#   'alcoholic'],
#  ['nobleman',
#   'posing',
#   'necktie',
#   'salesman',
#   'falls',
#   'love',
#   'daughter',
#   'circus',
#   'puppeteer',
#   'even',
#   'though',
#   'already',
#   'married',
#   'daughter',
#   'country',
#   'war',
#   'minister'],
#  ['silent',
#   'predecessor',
#   'modern',
#   'documentary',
#   'film',
#   'maker',
#   'robert',
#   'flaherty',
#   'spends',
#   'one',
#   'year',
#   'following',
#   'lives',
#   'nanook',
#   'family',
#   'inuit',
#   'living',
#   'arctic',
#   'circle'],
#  ['accident', 'buster', 'intimidating', 'woman', 'end', 'married'],
#  ['vampire',
#   'count',
#   'orlok',
#   'expresses',
#   'interest',
#   'new',
#   'residence',
#   'real',
#   'estate',
#   'agent',
#   'hutter',
#   'wife',
#   'silent',
#   'classic',
#   'based',
#   'story',
#   'dracula'],
#  ['unethical',
#   'merchant',
#   'moves',
#   'town',
#   'steals',
#   'customers',
#   'widowed',
#   'owner',
#   'established',
#   'store',
#   'gang',
#   'steps',
#   'help'],
#  ['shiftless',
#   'young',
#   'man',
#   'becomes',
#   'obsessed',
#   'mysterious',
#   'woman',
#   'yearns',
#   'find'],
#  ['salome',
#   'daughter',
#   'herodias',
#   'seduces',
#   'step',
#   'father',
#   'uncle',
#   'herod',
#   'governor',
#   'judea',
#   'salacious',
#   'dance',
#   'return',
#   'promises',
#   'head',
#   'prophet',
#   'john',
#   'baptist'],
#  ['nobleman',
#   'becomes',
#   'vigilante',
#   'robin',
#   'hood',
#   'protects',
#   'oppressed',
#   'english',
#   'people',
#   'tyrannical',
#   'prince',
#   'john'],
#  ['young',
#   'sherlock',
#   'holmes',
#   'seeks',
#   'bring',
#   'criminal',
#   'mastermind',
#   'moriarty',
#   'solves',
#   'crime',
#   'involving',
#   'blackmailed',
#   'prince'],
#  ['dinner',
#   'given',
#   'wealthy',
#   'baron',
#   'wive',
#   'attended',
#   'four',
#   'suitors',
#   'century',
#   'german',
#   'manor',
#   'shadow',
#   'player',
#   'rescues',
#   'marriage',
#   'giving',
#   'guests'],
#  ['wealthy',
#   'elias',
#   'graves',
#   'builds',
#   'home',
#   'top',
#   'hill',
#   'group',
#   'squatters',
#   'taken',
#   'residence',
#   'bottom',
#   'many',
#   'men',
#   'squatters',
#   'village',
#   'eyes'],
#  ['ethiopian',
#   'king',
#   'offers',
#   'daughter',
#   'powerful',
#   'pharaoh',
#   'secure',
#   'peace',
#   'two',
#   'countries'],
#  ['alice',
#   'visits',
#   'animation',
#   'studio',
#   'animators',
#   'show',
#   'various',
#   'scenes',
#   'drawing',
#   'boards',
#   'cat',
#   'dancing',
#   'cat',
#   'band',
#   'mouse',
#   'poking',
#   'live',
#   'cat'],
#  ['young',
#   'man',
#   'raised',
#   'american',
#   'south',
#   'discovers',
#   'indian',
#   'prince',
#   'whose',
#   'throne',
#   'taken',
#   'usurpers'],
#  ['hapless',
#   'amusement',
#   'park',
#   'attendant',
#   'finds',
#   'run',
#   'away',
#   'balloon',
#   'ride',
#   'left',
#   'strange',
#   'predicament'],
#  ['sue',
#   'graham',
#   'small',
#   'town',
#   'girl',
#   'wants',
#   'motion',
#   'picture',
#   'star',
#   'wins',
#   'contract',
#   'picture',
#   'pretty',
#   'girl',
#   'sent',
#   'studio',
#   'instead',
#   'picture',
#   'arrives'],
#  ['sta',
#   'berling',
#   'young',
#   'attractive',
#   'minister',
#   'alcoholic',
#   'preaches',
#   'far',
#   'daring',
#   'finally',
#   'defrocked',
#   'leaves',
#   'town',
#   'disgrace',
#   'arrives'],
#  ['fifteenth',
#   'century',
#   'paris',
#   'brother',
#   'archdeacon',
#   'plots',
#   'gypsy',
#   'king',
#   'foment',
#   'peasant',
#   'revolt',
#   'meanwhile',
#   'freakish',
#   'hunchback',
#   'falls',
#   'love',
#   'gypsy',
#   'queen'],
#  ['attempt',
#   'forget',
#   'lost',
#   'sweetheart',
#   'buster',
#   'takes',
#   'long',
#   'trip',
#   'sea',
#   'boards',
#   'whaling',
#   'ship',
#   'strict',
#   'captain'],
#  ['man',
#   'returns',
#   'appalachian',
#   'homestead',
#   'trip',
#   'falls',
#   'young',
#   'woman',
#   'problem',
#   'family',
#   'vowed',
#   'kill',
#   'every',
#   'member',
#   'family'],
#  ['tramp',
#   'escaped',
#   'convict',
#   'mistaken',
#   'pastor',
#   'small',
#   'town',
#   'church'],
#  ['sisif',
#   'railwayman',
#   'son',
#   'elie',
#   'fall',
#   'love',
#   'beautiful',
#   'norma',
#   'sisif',
#   'rescued',
#   'train',
#   'crash',
#   'baby',
#   'raised',
#   'daughter',
#   'tragic',
#   'results',
#   'originally'],
#  ['store',
#   'clerk',
#   'organizes',
#   'publicity',
#   'stunt',
#   'friend',
#   'climbs',
#   'outside',
#   'tall',
#   'building',
#   'circumstances',
#   'force',
#   'make',
#   'perilous',
#   'climb'],
#  ['nobleman',
#   'murders',
#   'best',
#   'friend',
#   'lawyer',
#   'becomes',
#   'revolutionary',
#   'heart',
#   'set',
#   'vengeance'],
#  ['young', 'woman', 'hits', 'hollywood', 'determined', 'become', 'star'],
#  ['misadventures', 'buster', 'three', 'separate', 'historical', 'periods'],
#  ['first',
#   'part',
#   'tells',
#   'story',
#   'moses',
#   'leading',
#   'jews',
#   'egypt',
#   'promised',
#   'land',
#   'receipt',
#   'tablets',
#   'worship',
#   'golden',
#   'calf',
#   'second',
#   'part',
#   'shows',
#   'efficacy'],
#  ['owner',
#   'waxmuseum',
#   'needs',
#   'three',
#   'models',
#   'stories',
#   'told',
#   'audience',
#   'reason',
#   'hired',
#   'writer',
#   'one',
#   'look',
#   'athe',
#   'owner',
#   'pretty',
#   'daughter',
#   'starts'],
#  ['young',
#   'woman',
#   'becomes',
#   'nun',
#   'believes',
#   'sweetheart',
#   'killed',
#   'things',
#   'get',
#   'complicated',
#   'returns',
#   'alive'],
#  ['harold',
#   'van',
#   'pelham',
#   'lloyd',
#   'hypochondriac',
#   'rich',
#   'businessman',
#   'sails',
#   'tropics',
#   'health',
#   'instead',
#   'peace',
#   'seclusion',
#   'seeking',
#   'finds',
#   'middle'],
#  ['kept',
#   'woman',
#   'runs',
#   'one',
#   'time',
#   'fianc',
#   'finds',
#   'torn',
#   'love',
#   'comfort'],
#  ['called',
#   'first',
#   'soviet',
#   'science',
#   'fiction',
#   'film',
#   'futuristic',
#   'sets',
#   'mars',
#   'although',
#   'takes',
#   'place',
#   'moscow',
#   'movie',
#   'set',
#   'beginning',
#   'nep',
#   'new'],
#  ['story', 'family', 'caught', 'american', 'revolutionary', 'war'],
#  ['george',
#   'bryan',
#   'brummel',
#   'british',
#   'military',
#   'officer',
#   'loves',
#   'lady',
#   'margery',
#   'betrothed',
#   'lord',
#   'alvanley',
#   'despite',
#   'desperate',
#   'love',
#   'brummel',
#   'submits',
#   'family',
#   'pressure',
#   'marries'],
#  ['lighthouse',
#   'keeper',
#   'finds',
#   'little',
#   'girl',
#   'washed',
#   'ashore',
#   'tied',
#   'wreckage',
#   'adopts',
#   'become',
#   'inseparable',
#   'eventually',
#   'real',
#   'family',
#   'finds',
#   'tries',
#   'take',
#   'away'],
#  ['absolute',
#   'dada',
#   'movie',
#   'somebody',
#   'gets',
#   'killed',
#   'coffin',
#   'gets',
#   'control',
#   'chase',
#   'stops',
#   'person',
#   'gets',
#   'let',
#   'everybody',
#   'followed',
#   'coffin',
#   'dissapear'],
#  ['likeable',
#   'carefree',
#   'grand',
#   'duke',
#   'abacco',
#   'dire',
#   'straits',
#   'money',
#   'left',
#   'service',
#   'state',
#   'debt',
#   'main',
#   'creditor',
#   'looking',
#   'forward',
#   'expropriating',
#   'entire',
#   'duchy'],
#  ['shy',
#   'young',
#   'man',
#   'completely',
#   'incapable',
#   'talking',
#   'women',
#   'decides',
#   'write',
#   'book',
#   'details',
#   'bachelors',
#   'find',
#   'girlfriend'],
#  ['bitter',
#   'clown',
#   'endeavors',
#   'rescue',
#   'young',
#   'woman',
#   'loves',
#   'lecherous',
#   'count',
#   'betrayed'],
#  ['claire',
#   'lescot',
#   'famous',
#   'prima',
#   'donna',
#   'men',
#   'want',
#   'loved',
#   'among',
#   'young',
#   'scientist',
#   'einar',
#   'norsen',
#   'mocks',
#   'leaves',
#   'house',
#   'declared'],
#  ['episodic',
#   'look',
#   'married',
#   'life',
#   'law',
#   'problems',
#   'adventures',
#   'include',
#   'ride',
#   'crowded',
#   'trolley',
#   'live',
#   'turkey',
#   'wild',
#   'spin',
#   'new',
#   'auto',
#   'laws',
#   'tow',
#   'sequence'],
#  ['springfield',
#   'illinois',
#   'brandon',
#   'surveyor',
#   'dreams',
#   'building',
#   'railway',
#   'west',
#   'marsh',
#   'contractor',
#   'sceptical',
#   'abraham',
#   'lincoln',
#   'looks',
#   'children',
#   'davy',
#   'brandon'],
#  ['famous',
#   'shakespearean',
#   'actor',
#   'falls',
#   'love',
#   'woman',
#   'station',
#   'professional',
#   'personal',
#   'life',
#   'begin',
#   'crumble'],
#  ['aging',
#   'doorman',
#   'fired',
#   'prestigious',
#   'job',
#   'luxurious',
#   'hotel',
#   'forced',
#   'face',
#   'scorn',
#   'friends',
#   'neighbours',
#   'society'],
#  ['professor',
#   'stock',
#   'wife',
#   'mizzi',
#   'always',
#   'bickering',
#   'mizzi',
#   'tries',
#   'seduce',
#   'franz',
#   'braun',
#   'new',
#   'husband',
#   'good',
#   'friend',
#   'charlotte',
#   'braun',
#   'colleague',
#   'mueller'],
#  ['triangle',
#   'story',
#   'painter',
#   'young',
#   'male',
#   'model',
#   'unscrupulous',
#   'princess'],
#  ['two',
#   'spoiled',
#   'rich',
#   'people',
#   'find',
#   'trapped',
#   'empty',
#   'passenger',
#   'ship'],
#  ['siegfried',
#   'dead',
#   'kriemhild',
#   'marries',
#   'etzel',
#   'king',
#   'huns',
#   'gives',
#   'birth',
#   'child',
#   'invites',
#   'brothers',
#   'party',
#   'tries',
#   'persuade',
#   'etzel',
#   'huns'],
#  ['siegfried',
#   'son',
#   'king',
#   'sigmund',
#   'hears',
#   'beautiful',
#   'sister',
#   'gunter',
#   'king',
#   'worms',
#   'kriemhild',
#   'way',
#   'worms',
#   'kills',
#   'dragon',
#   'finds',
#   'treasure',
#   'hort',
#   'helps',
#   'gunther'],
#  ['works',
#   'tedious',
#   'office',
#   'job',
#   'maria',
#   'ivanovna',
#   'dreams',
#   'married',
#   'particular',
#   'hopes',
#   'worker',
#   'nikodim',
#   'mityushin',
#   'take',
#   'interest',
#   'nikodim'],
#  ['world',
#   'famous',
#   'pianist',
#   'loses',
#   'hands',
#   'accident',
#   'new',
#   'hands',
#   'grafted',
#   'know',
#   'belonged',
#   'murderer'],
#  ['peter',
#   'pan',
#   'enters',
#   'nursery',
#   'darling',
#   'children',
#   'help',
#   'fairy',
#   'dust',
#   'leads',
#   'never',
#   'never',
#   'land',
#   'meet',
#   'nefarious',
#   'captain',
#   'hook'],
#  ['two',
#   'young',
#   'lovers',
#   'escape',
#   'past',
#   'lives',
#   'paris',
#   'fate',
#   'separates'],
#  ['wrongly',
#   'convicted',
#   'english',
#   'gentleman',
#   'goes',
#   'galley',
#   'slave',
#   'pirate',
#   'captain'],
#  ['film',
#   'projectionist',
#   'longs',
#   'detective',
#   'puts',
#   'meagre',
#   'skills',
#   'work',
#   'framed',
#   'rival',
#   'stealing',
#   'girlfriend',
#   'father',
#   'pocketwatch'],
#  ['group',
#   'oppressed',
#   'factory',
#   'workers',
#   'strike',
#   'pre',
#   'revolutionary',
#   'russia'],
#  ['recalcitrant',
#   'thief',
#   'vies',
#   'duplicitous',
#   'mongol',
#   'ruler',
#   'hand',
#   'beautiful',
#   'princess'],
#  ['millie',
#   'stope',
#   'lives',
#   'grandfather',
#   'remote',
#   'island',
#   'grandfather',
#   'fled',
#   'political',
#   'reasons',
#   'alone',
#   'escaped',
#   'prisoner',
#   'nicholas',
#   'terrorizing'],
#  ['minister',
#   'malevolent',
#   'sinister',
#   'behind',
#   'righteous',
#   'facade',
#   'consorts',
#   'later',
#   'extorts',
#   'owner',
#   'gambling',
#   'house',
#   'betrays',
#   'honest',
#   'girl',
#   'eventually',
#   'driving'],
#  ['young', 'american', 'soldier', 'witnesses', 'horrors', 'great', 'war'],
#  ['dramatized',
#   'account',
#   'great',
#   'russian',
#   'naval',
#   'mutiny',
#   'resulting',
#   'street',
#   'demonstration',
#   'brought',
#   'police',
#   'massacre'],
#  ['penniless',
#   'skirt',
#   'chasing',
#   'italian',
#   'nobleman',
#   'finds',
#   'love',
#   'scandal',
#   'travels',
#   'new',
#   'york',
#   'city'],
#  ['cesar',
#   'son',
#   'zorro',
#   'framed',
#   'murder',
#   'visiting',
#   'spain',
#   'becomes',
#   'whip',
#   'wielding',
#   'outlaw'],
#  ['victor',
#   'frandsen',
#   'domestic',
#   'tyrant',
#   'wife',
#   'ida',
#   'work',
#   'slave',
#   'rest',
#   'family',
#   'rises',
#   'early',
#   'prepare',
#   'everything',
#   'day',
#   'toils',
#   'day',
#   'long'],
#  ['mathias',
#   'pascal',
#   'son',
#   'rich',
#   'family',
#   'marries',
#   'beautiful',
#   'romalinda',
#   'terrible',
#   'mother',
#   'law',
#   'controls',
#   'daughter',
#   'soon',
#   'home',
#   'life',
#   'becomes',
#   'nightmare',
#   'well'],
#  ['vienna',
#   'biggest',
#   'depression',
#   'directly',
#   'slum',
#   'lila',
#   'leid',
#   'wife',
#   'lawyer',
#   'leid',
#   'murdered',
#   'egon',
#   'secretary',
#   'one',
#   'leid',
#   'clients',
#   'arrested'],
#  ['nerdy', 'college', 'student', 'anything', 'become', 'popular', 'campus'],
#  ['little',
#   'luck',
#   'keeping',
#   'job',
#   'city',
#   'new',
#   'yorker',
#   'tries',
#   'work',
#   'country',
#   'eventually',
#   'finds',
#   'way',
#   'leading',
#   'herd',
#   'cattle',
#   'west',
#   'coast'],
#  ['struggles',
#   'hardscrabble',
#   'iranian',
#   'nomadic',
#   'tribe',
#   'journey',
#   'bleak',
#   'country',
#   'reach',
#   'grasslands',
#   'save',
#   'livestock'],
#  ['sudden',
#   'fortune',
#   'lottery',
#   'fans',
#   'destructive',
#   'greed',
#   'ruins',
#   'lives',
#   'three',
#   'people',
#   'involved'],
#  ['prospector', 'goes', 'klondike', 'search', 'gold', 'finds'],
#  ['mrs',
#   'erlynne',
#   'mother',
#   'lady',
#   'windermere',
#   'daughter',
#   'know',
#   'wants',
#   'introduced',
#   'society',
#   'marry',
#   'lord',
#   'augustus',
#   'lorton',
#   'lord',
#   'windermere'],
#  ['first',
#   'film',
#   'adaptation',
#   'sir',
#   'arthur',
#   'conan',
#   'doyle',
#   'classic',
#   'novel',
#   'land',
#   'prehistoric',
#   'creatures',
#   'still',
#   'roam'],
#  ['southern',
#   'belle',
#   'elizabeth',
#   'lloyd',
#   'runs',
#   'marry',
#   'yankee',
#   'jack',
#   'sherman',
#   'father',
#   'former',
#   'confederate',
#   'colonel',
#   'civil',
#   'war',
#   'vows',
#   'never',
#   'speak',
#   'several',
#   'years'],
#  ['although',
#   'parents',
#   'warned',
#   'stay',
#   'away',
#   'movies',
#   'hero',
#   'winds',
#   'acting',
#   'costume',
#   'picture',
#   'doubling',
#   'comedian',
#   'lloyd',
#   'hamilton'],
#  ['prince',
#   'must',
#   'woo',
#   'wealthy',
#   'dancer',
#   'abandoned',
#   'order',
#   'keep',
#   'money',
#   'country',
#   'order',
#   'keep',
#   'crashing',
#   'economically'],
#  ['mad',
#   'disfigured',
#   'composer',
#   'seeks',
#   'love',
#   'lovely',
#   'young',
#   'opera',
#   'singer'],
#  ['street',
#   'people',
#   'armand',
#   'marie',
#   'madly',
#   'love',
#   'persuades',
#   'armand',
#   'gang',
#   'members',
#   'rob',
#   'home',
#   'pierre',
#   'marcel',
#   'wealthy',
#   'scientist',
#   'police',
#   'break',
#   'robbery'],
#  ['hugh',
#   'carver',
#   'athletic',
#   'star',
#   'freshman',
#   'prescott',
#   'college',
#   'falls',
#   'love',
#   'cynthia',
#   'day',
#   'popular',
#   'girl',
#   'loves',
#   'parties',
#   'finds',
#   'impossible',
#   'please'],
#  ['patsy',
#   'brand',
#   'chorus',
#   'girl',
#   'pleasure',
#   'garden',
#   'music',
#   'hall',
#   'meets',
#   'jill',
#   'cheyne',
#   'luck',
#   'gets',
#   'job',
#   'dancer',
#   'jill',
#   'engaged',
#   'adventurer',
#   'hugh',
#   'fielding'],
#  ['fran',
#   'ois',
#   'mother',
#   'mme',
#   'lepic',
#   'hates',
#   'nicknames',
#   'poil',
#   'carotte',
#   'carrot',
#   'hair',
#   'father',
#   'interested',
#   'politics',
#   'hunting',
#   'spite'],
#  ['small',
#   'town',
#   'girl',
#   'finds',
#   'escape',
#   'cruel',
#   'home',
#   'life',
#   'arms',
#   'handsome',
#   'stranger',
#   'soon',
#   'finds',
#   'working',
#   'prostitute',
#   'new',
#   'orleans',
#   'desperately',
#   'clinging',
#   'belief',
#   'really',
#   'loves'],
#  ['man', 'learns', 'inherit', 'fortune', 'marries', 'today'],
#  ['jews', 'expelled', 'city', 'utopia'],
#  ['history',
#   'portrayed',
#   'film',
#   'succession',
#   'conquests',
#   'stronger',
#   'races',
#   'weaker',
#   'ones',
#   'played',
#   'stage',
#   'monument',
#   'valley',
#   'long',
#   'ago',
#   'tribes',
#   'indians'],
#  ['prologue',
#   'murderer',
#   'boss',
#   'huller',
#   'spent',
#   'ten',
#   'years',
#   'prison',
#   'breaks',
#   'silence',
#   'tell',
#   'warden',
#   'story',
#   'boss',
#   'former',
#   'trapeze',
#   'artist',
#   'wife',
#   'cheap'],
#  ['sideshow',
#   'ventriloquist',
#   'midget',
#   'strongman',
#   'form',
#   'conspiracy',
#   'known',
#   'unholy',
#   'three',
#   'commit',
#   'series',
#   'robberies'],
#  ['dorothy',
#   'heir',
#   'throne',
#   'must',
#   'take',
#   'back',
#   'wicked',
#   'prime',
#   'minister',
#   'kruel',
#   'help',
#   'three',
#   'farmhands'],
#  ['rafael',
#   'sabatini',
#   'story',
#   'swashbuckling',
#   'era',
#   'bardeleys',
#   'handsome',
#   'courtier',
#   'could',
#   'win',
#   'woman',
#   'set',
#   'mind',
#   'boasting',
#   'would',
#   'listen'],
#  ['masked',
#   'criminal',
#   'dresses',
#   'like',
#   'giant',
#   'bat',
#   'terrorizes',
#   'guests',
#   'old',
#   'house',
#   'rented',
#   'mystery',
#   'writer'],
#  ['love',
#   'struck',
#   'weakling',
#   'must',
#   'pretend',
#   'boxer',
#   'order',
#   'gain',
#   'respect',
#   'family',
#   'girl',
#   'loves'],
#  ['jewish',
#   'prince',
#   'seeks',
#   'find',
#   'family',
#   'revenge',
#   'upon',
#   'childhood',
#   'friend',
#   'wrongly',
#   'imprisoned'],
#  ['two',
#   'thieves',
#   'blackbird',
#   'west',
#   'end',
#   'bertie',
#   'fall',
#   'love',
#   'girl',
#   'french',
#   'nightclub',
#   'performer',
#   'named',
#   'fifi',
#   'man',
#   'tries',
#   'outdo',
#   'win',
#   'heart'],
#  ['innkeeper',
#   'murders',
#   'wealthy',
#   'guest',
#   'pay',
#   'debt',
#   'conscience',
#   'allow',
#   'get',
#   'away',
#   'crime',
#   'easily'],
#  ['group',
#   'starving',
#   'artists',
#   'try',
#   'survive',
#   'paris',
#   'including',
#   'seamstress',
#   'would',
#   'playwright',
#   'loves'],
#  ['tom',
#   'brown',
#   'shows',
#   'harvard',
#   'confident',
#   'bit',
#   'arrogant',
#   'becomes',
#   'rival',
#   'bob',
#   'mcandrew',
#   'football',
#   'rowing',
#   'crew',
#   'also',
#   'affections',
#   'mary',
#   'abbott'],
#  ['idealistic',
#   'farm',
#   'boy',
#   'peter',
#   'loves',
#   'amy',
#   'whose',
#   'fancy',
#   'urbane',
#   'harry',
#   'discovers',
#   'harry',
# ...
#   'leans',
#   'toward',
#   'christianity'],
#  ['insane',
#   'surgeon',
#   'obsession',
#   'actress',
#   'leads',
#   'replace',
#   'husband',
#   'hands',
#   'hands',
#   'knife',
#   'murderer',
#   'still',
#   'urge',
#   'throw',
#   'knives'],
#  ['young', 'girl', 'slowly', 'becomes', 'dope', 'pusher'],
#  ['three',
#   'british',
#   'soldiers',
#   'northwest',
#   'frontier',
#   'india',
#   'struggle',
#   'invaders'],
#  ['nobleman',
#   'murdered',
#   'professor',
#   'occult',
#   'blames',
#   'vampires',
#   'seems'],
#  ['hard',
#   'working',
#   'henpecked',
#   'ambrose',
#   'wolfinger',
#   'takes',
#   'work',
#   'wrestling',
#   'match',
#   'catastrophic',
#   'consequences'],
#  ['end',
#   'century',
#   'rome',
#   'ruled',
#   'ruthlessly',
#   'power',
#   'mad',
#   'sex',
#   'hungry',
#   'cesare',
#   'borgia',
#   'eldest',
#   'son',
#   'pope',
#   'alexander',
#   'following',
#   'advice',
#   'chief',
#   'adviser',
#   'niccolo'],
#  ['theseus',
#   'duke',
#   'athens',
#   'going',
#   'marry',
#   'hyppolyta',
#   'queen',
#   'amazons',
#   'demetrius',
#   'engaged',
#   'hermia',
#   'hermia',
#   'loves',
#   'lysander',
#   'helena',
#   'loves',
#   'demetrius',
#   'oberon',
#   'titania'],
#  ['early',
#   'century',
#   'france',
#   'convict',
#   'failed',
#   'report',
#   'parole',
#   'relentlessly',
#   'pursued',
#   'year',
#   'period',
#   'obsessive',
#   'policeman'],
#  ['fletcher',
#   'christian',
#   'successfully',
#   'leads',
#   'revolt',
#   'ruthless',
#   'captain',
#   'bligh',
#   'hms',
#   'bounty',
#   'however',
#   'bligh',
#   'returns',
#   'one',
#   'year',
#   'later',
#   'hell',
#   'bent',
#   'avenging',
#   'captors'],
#  ['texas', 'ranger', 'tries', 'stop', 'takeover', 'indian', 'lands'],
#  ['investigating',
#   'series',
#   'murders',
#   'chinatown',
#   'wise',
#   'guy',
#   'reporter',
#   'jason',
#   'barton',
#   'captured',
#   'megalomaniacal',
#   'wong',
#   'desperately',
#   'trying',
#   'complete',
#   'collection',
#   'twelve',
#   'gold'],
#  ['opium',
#   'addicted',
#   'choirmaster',
#   'develops',
#   'obsession',
#   'beautiful',
#   'young',
#   'girl',
#   'stop',
#   'short',
#   'murder',
#   'order'],
#  ['horrific',
#   'storm',
#   'sea',
#   'crew',
#   'realizes',
#   'murderer',
#   'among',
#   'killing',
#   'one',
#   'one'],
#  ['order',
#   'avoid',
#   'prearranged',
#   'marriage',
#   'rebellious',
#   'french',
#   'princess',
#   'sheds',
#   'identity',
#   'escapes',
#   'colonial',
#   'new',
#   'orleans',
#   'finds',
#   'unlikely',
#   'true',
#   'love'],
#  ['sly',
#   'business',
#   'manager',
#   'two',
#   'wacky',
#   'friends',
#   'two',
#   'opera',
#   'singers',
#   'help',
#   'achieve',
#   'success',
#   'humiliating',
#   'stuffy',
#   'snobbish',
#   'enemies'],
#  ['middleton',
#   'caught',
#   'work',
#   'neglects',
#   'wife',
#   'elsa',
#   'lonely',
#   'elsa',
#   'begins',
#   'spend',
#   'time',
#   'best',
#   'friend',
#   'become',
#   'attracted',
#   'one',
#   'another',
#   'elsa'],
#  ['loretta',
#   'dalrymple',
#   'homely',
#   'young',
#   'country',
#   'girl',
#   'comes',
#   'new',
#   'york',
#   'city',
#   'gets',
#   'job',
#   'chambermaid',
#   'large',
#   'hotel',
#   'meets',
#   'olson',
#   'photographer',
#   'work',
#   'dan',
#   'riley'],
#  ['sent',
#   'find',
#   'counterfeiters',
#   'john',
#   'wyatt',
#   'joins',
#   'doc',
#   'carter',
#   'medicine',
#   'show',
#   'arrive',
#   'town',
#   'curly',
#   'joe',
#   'runs',
#   'counterfeiting',
#   'operation',
#   'carter',
#   'framed',
#   'curly',
#   'joe'],
#  ['french', 'novelist', 'passes', 'african', 'shepherdess', 'princess'],
#  ['john',
#   'martin',
#   'government',
#   'agent',
#   'working',
#   'cover',
#   'leading',
#   'citizen',
#   'morgan',
#   'calls',
#   'gunman',
#   'galt',
#   'blows',
#   'martin',
#   'cover'],
#  ['bill',
#   'gordon',
#   'headed',
#   'france',
#   'meets',
#   'becomes',
#   'friendly',
#   'joel',
#   'carter',
#   'niece',
#   'asst',
#   'secretary',
#   'war',
#   'finding',
#   'expert',
#   'codes',
#   'gets'],
#  ['brilliant',
#   'surgeon',
#   'obsessed',
#   'poe',
#   'saves',
#   'life',
#   'beautiful',
#   'dancer',
#   'goes',
#   'mad'],
#  ['pluto',
#   'chases',
#   'kitten',
#   'window',
#   'right',
#   'mickey',
#   'lap',
#   'mickey',
#   'scolds',
#   'goes',
#   'wash',
#   'kitten',
#   'pluto',
#   'falls',
#   'asleep',
#   'front',
#   'fire',
#   'dreams',
#   'hell',
#   'ruled'],
#  ['rebellious',
#   'daughter',
#   'army',
#   'general',
#   'gets',
#   'involved',
#   'communist',
#   'agitator',
#   'mainly',
#   'annoy',
#   'father',
#   'arranges',
#   'kidnapped',
#   'taken',
#   'mexico',
#   'hoping'],
#  ['football',
#   'player',
#   'john',
#   'kent',
#   'tags',
#   'along',
#   'huck',
#   'haines',
#   'wabash',
#   'indianians',
#   'travel',
#   'engagement',
#   'paris',
#   'lose',
#   'immediately',
#   'john',
#   'company',
#   'visit',
#   'aunt',
#   'owner',
#   'posh'],
#  ['fisherman',
#   'dutch',
#   'marries',
#   'cannery',
#   'worker',
#   'hattie',
#   'quits',
#   'poorly',
#   'paid',
#   'job',
#   'concentrate',
#   'getting',
#   'better',
#   'working',
#   'conditions',
#   'union',
#   'leader',
#   'unfortunately',
#   'union',
#   'members',
#   'disagree'],
#  ['english',
#   'valet',
#   'brought',
#   'american',
#   'west',
#   'assimilates',
#   'american',
#   'way',
#   'life'],
#  ['british',
#   'district',
#   'officer',
#   'nigeria',
#   'rules',
#   'area',
#   'strictly',
#   'justly',
#   'struggles',
#   'gun',
#   'runners',
#   'slavers',
#   'aid',
#   'loyal',
#   'native',
#   'chief'],
#  ['scrooge',
#   'ultimate',
#   'victorian',
#   'miser',
#   'good',
#   'word',
#   'christmas',
#   'though',
#   'impoverished',
#   'clerk',
#   'cratchit',
#   'nephew',
#   'fred',
#   'full',
#   'holiday',
#   'spirit',
#   'night',
#   'scrooge'],
#  ['leo',
#   'vincey',
#   'told',
#   'dying',
#   'uncle',
#   'lost',
#   'land',
#   'visited',
#   'years',
#   'ago',
#   'ancestor',
#   'heads',
#   'family',
#   'friend',
#   'horace',
#   'holly',
#   'try',
#   'discover',
#   'land',
#   'secret',
#   'immortality'],
#  ['dancer',
#   'disappears',
#   'theather',
#   'william',
#   'powell',
#   'society',
#   'beauty',
#   'ginger',
#   'rogers',
#   'solve',
#   'murder'],
#  ['louisiana',
#   'con',
#   'man',
#   'enters',
#   'steamboat',
#   'winner',
#   'take',
#   'race',
#   'rival',
#   'trying',
#   'find',
#   'witness',
#   'free',
#   'nephew',
#   'hung',
#   'murder'],
#  ['escaping',
#   'england',
#   'french',
#   'embezzlement',
#   'charge',
#   'widower',
#   'henry',
#   'scarlett',
#   'accompanied',
#   'daughter',
#   'sylvia',
#   'avoid',
#   'detection',
#   'disguises',
#   'boy',
#   'sylvester'],
#  ['swedenhielms',
#   'old',
#   'aristocratic',
#   'family',
#   'head',
#   'family',
#   'professor',
#   'rolf',
#   'swedenhielm',
#   'three',
#   'children',
#   'julia',
#   'rolf',
#   'also',
#   'live',
#   'house',
#   'also'],
#  ['pair',
#   'lookalikes',
#   'one',
#   'former',
#   'french',
#   'aristocrat',
#   'alcoholic',
#   'english',
#   'lawyer',
#   'fall',
#   'love',
#   'woman',
#   'amongst',
#   'turmoil',
#   'french',
#   'revolution'],
#  ['sheriff',
#   'john',
#   'higgins',
#   'quits',
#   'goes',
#   'prospecting',
#   'thinks',
#   'killed',
#   'best',
#   'friend',
#   'shooting',
#   'robbers',
#   'encounters',
#   'dead',
#   'buddy',
#   'sister',
#   'helps',
#   'run'],
#  ['three',
#   'orphan',
#   'kittens',
#   'entering',
#   'society',
#   'house',
#   'winter',
#   'ruin',
#   'furniture',
#   'caught',
#   'maid',
#   'young',
#   'daughter',
#   'house',
#   'rescues',
#   'cold'],
#  ['american',
#   'dancer',
#   'comes',
#   'britain',
#   'falls',
#   'model',
#   'initially',
#   'annoyed',
#   'mistakes',
#   'goofy',
#   'producer'],
#  ['team',
#   'international',
#   'scientists',
#   'engineers',
#   'attempts',
#   'build',
#   'tunnel',
#   'ocean'],
#  ['max',
#   'hare',
#   'toby',
#   'tortoise',
#   'foot',
#   'race',
#   'max',
#   'much',
#   'style',
#   'generally',
#   'cocky',
#   'pauses',
#   'short',
#   'nap',
#   'chat',
#   'bunnies',
#   'outside',
#   'girl',
#   'school',
#   'show'],
#  ['angela',
#   'tritchell',
#   'daughter',
#   'tooth',
#   'paste',
#   'manufacturer',
#   'rufus',
#   'twitchell',
#   'monopolized',
#   'business',
#   'many',
#   'years',
#   'grown',
#   'conservative',
#   'rivals',
#   'begin'],
#  ['finances',
#   'low',
#   'seeking',
#   'background',
#   'new',
#   'book',
#   'author',
#   'tony',
#   'barratt',
#   'wife',
#   'dora',
#   'return',
#   'country',
#   'home',
#   'conneecticut',
#   'finding',
#   'theme'],
#  ['youngster',
#   'john',
#   'wyatt',
#   'saw',
#   'parents',
#   'killed',
#   'brother',
#   'kidnapped',
#   'wagon',
#   'train',
#   'heading',
#   'west',
#   'meets',
#   'brother',
#   'spy',
#   'gang',
#   'originally',
#   'dirty',
#   'work',
#   'brother',
#   'fall',
#   'mary',
#   'gordon'],
#  ['juice',
#   'rare',
#   'tibetan',
#   'flower',
#   'thing',
#   'keeps',
#   'glendon',
#   'turning',
#   'werewolf',
#   'full',
#   'moon'],
#  ['meek',
#   'milquetoast',
#   'clerk',
#   'mistaken',
#   'public',
#   'enemy',
#   'notorious',
#   'killer',
#   'takes',
#   'advantage',
#   'situation'],
#  ['dedicated',
#   'pursuit',
#   'technology',
#   'aid',
#   'pilots',
#   'safely',
#   'fly',
#   'blind',
#   'adverse',
#   'conditions',
#   'aerial',
#   'innovator',
#   'ken',
#   'gordon',
#   'literally',
#   'blinded',
#   'accident',
#   'setback',
#   'deter',
#   'goal'],
#  ['cardsharp', 'comes', 'aid', 'mexican', 'family'],
#  ['swiss',
#   'alps',
#   'mickey',
#   'mouse',
#   'tangles',
#   'mother',
#   'eagle',
#   'donald',
#   'duck',
#   'scraps',
#   'edelweiss',
#   'stealing',
#   'goat',
#   'pluto',
#   'gets',
#   'inebriated',
#   'bernard'],
#  ['nick',
#   'investigates',
#   'case',
#   'missing',
#   'man',
#   'later',
#   'murder',
#   'connected',
#   'nora',
#   'family'],
#  ['century',
#   'italy',
#   'orphan',
#   'debt',
#   'man',
#   'raised',
#   'threatens',
#   'separate',
#   'forever',
#   'woman',
#   'loves'],
#  ['bored',
#   'millionaire',
#   'wagers',
#   'doctor',
#   'support',
#   'working',
#   'class',
#   'job',
#   'year',
#   'without',
#   'touching',
#   'inheritance'],
#  ['charismatic',
#   'thief',
#   'makes',
#   'friends',
#   'bankrupt',
#   'baron',
#   'comes',
#   'live',
#   'thief',
#   'slum',
#   'meanwhile',
#   'thief',
#   'seeks',
#   'love',
#   'young',
#   'woman',
#   'held',
#   'emotionally',
#   'captive',
#   'slumlord',
#   'family'],
#  ['world',
#   'war',
#   'irish',
#   'rebels',
#   'launch',
#   'uprising',
#   'aim',
#   'creating',
#   'irish',
#   'republic',
#   'independent',
#   'united',
#   'kingdom',
#   'great',
#   'britain',
#   'ireland',
#   'one',
#   'rebellion',
#   'leaders'],
#  ['sassy',
#   'manicurist',
#   'eve',
#   'fallon',
#   'recruited',
#   'even',
#   'brassy',
#   'reporter',
#   'helps',
#   'police',
#   'detective',
#   'boyfriend',
#   'danny',
#   'barr',
#   'break',
#   'jewel',
#   'theft',
#   'ring',
#   'solve',
#   'murder',
#   'baby'],
#  ['hard',
#   'working',
#   'machinist',
#   'loses',
#   'promotion',
#   'polish',
#   'born',
#   'worker',
#   'seduced',
#   'joining',
#   'secretive',
#   'black',
#   'legion',
#   'intimidates',
#   'foreigners',
#   'violence'],
#  ['thank',
#   'kindly',
#   'young',
#   'driver',
#   'local',
#   'bus',
#   'traveling',
#   'poverty',
#   'stricken',
#   'coastal',
#   'villages',
#   'mountains',
#   'town',
#   'thanks',
#   'everybody',
#   'let',
#   'bus',
#   'pass'],
#  ['band',
#   'gypsies',
#   'camped',
#   'outside',
#   'walls',
#   'count',
#   'arnheim',
#   'palace',
#   'oliver',
#   'wife',
#   'kidnaps',
#   'count',
#   'daughter',
#   'arline',
#   'leaves',
#   'child',
#   'runs',
#   'lover',
#   'devilshoof'],
#  ['extremely',
#   'proud',
#   'michael',
#   'martin',
#   'made',
#   'fashion',
#   'model',
#   'carolyn',
#   'quit',
#   'job',
#   'marriage',
#   'carolyn',
#   'quickly',
#   'quietly',
#   'secretly',
#   'get',
#   'another',
#   'job',
#   'realizes',
#   'michael',
#   'successfully',
#   'make',
#   'financial',
#   'ends',
#   'meet',
#   'alone'],
#  ['talented',
#   'boxer',
#   'gifted',
#   'dancer',
#   'hope',
#   'increase',
#   'waning',
#   'popularity',
#   'inventing',
#   'fictitious',
#   'love',
#   'affair',
#   'benefit',
#   'tabloids'],
#  ['sailor',
#   'ted',
#   'meets',
#   'lonely',
#   'hearts',
#   'club',
#   'friend',
#   'gunny',
#   'wife',
#   'jenny',
#   'girl',
#   'nora',
#   'paige',
#   'falls',
#   'love',
#   'nora',
#   'wants',
#   'become',
#   'dancer',
#   'broadway',
#   'ted',
#   'rescues',
#   'pekinese'],
#  ['police',
#   'captain',
#   'dan',
#   'mclaren',
#   'becomes',
#   'police',
#   'commissioner',
#   'former',
#   'detective',
#   'johnny',
#   'blake',
#   'knocks',
#   'convincing',
#   'rackets',
#   'boss',
#   'kruger',
#   'blake',
#   'sincere',
#   'effort',
#   'join'],
#  ['shirley',
#   'lives',
#   'lighthouse',
#   'keeper',
#   'rescued',
#   'parents',
#   'drowned',
#   'truant',
#   'officer',
#   'decides',
#   'boarding',
#   'school',
#   'rescued',
#   'relatives',
#   'buddy',
#   'ebsen',
#   'dances',
#   'codfish',
#   'ball',
#   'shirley'],
#  ['major',
#   'countermands',
#   'orders',
#   'attacks',
#   'revenge',
#   'previous',
#   'massacre',
#   'men',
#   'women',
#   'children'],
#  ['visiting',
#   'circus',
#   'family',
#   'charlie',
#   'recruited',
#   'big',
#   'top',
#   'owner',
#   'investigate',
#   'threatening',
#   'letters',
#   'received'],
#  ['orphanage',
#   'children',
#   'sad',
#   'received',
#   'broken',
#   'toys',
#   'gifts',
#   'professor',
#   'grampy',
#   'sees',
#   'children',
#   'passing',
#   'sled',
#   'idea',
#   'give',
#   'merry',
#   'christmas'],
#  ['heir', 'huge', 'fortune', 'presumed', 'drowned', 'shows', 'murdered'],
#  ['dangerous',
#   'amnesiac',
#   'escapes',
#   'asylum',
#   'hides',
#   'opera',
#   'house',
#   'suspected',
#   'getting',
#   'revenge',
#   'tried',
#   'murder',
#   'years',
#   'ago'],
#  ['ambitious',
#   'lumberjack',
#   'abandons',
#   'saloon',
#   'girl',
#   'lover',
#   'marry',
#   'wealth',
#   'years',
#   'later',
#   'becomes',
#   'infatuated',
#   'woman',
#   'daughter'],
#  ['domineering',
#   'woman',
#   'marries',
#   'wealthy',
#   'man',
#   'money',
#   'uses',
#   'position',
#   'ambitions',
#   'money',
#   'power'],
#  ['man',
#   'woman',
#   'arrive',
#   'cafe',
#   'hotel',
#   'near',
#   'belgian',
#   'frontier',
#   'customers',
#   'recognize',
#   'man',
#   'police',
#   'description',
#   'name',
#   'amedee',
#   'lange',
#   'murdered',
#   'batala',
#   'paris'],
#  ['honor',
#   'panisse',
#   'dying',
#   'cheerfully',
#   'friends',
#   'wife',
#   'son',
#   'side',
#   'confesses',
#   'priest',
#   'front',
#   'friends',
#   'insists',
#   'doctor',
#   'truthful'],
#  ['automotive',
#   'engineer',
#   'bound',
#   'holiday',
#   'spain',
#   'meets',
#   'sultry',
#   'jewel',
#   'thief'],
#  ['escaped',
#   'devil',
#   'island',
#   'convict',
#   'uses',
#   'miniaturized',
#   'humans',
#   'wreak',
#   'vengeance',
#   'framed'],
#  ['dimples',
#   'appleby',
#   'lives',
#   'pick',
#   'pocket',
#   'grandfather',
#   'century',
#   'new',
#   'york',
#   'city',
#   'entertains',
#   'crowds',
#   'works',
#   'racket',
#   'rich',
#   'lady',
#   'makes',
#   'possible',
#   'girl',
#   'legit',
#   'uncle',
#   'tom',
#   'cabin',
#   'performed'],
#  ['french',
#   'farce',
#   'set',
#   'victorian',
#   'london',
#   'botanist',
#   'wife',
#   'get',
#   'trouble',
#   'pretend',
#   'missing',
#   'order',
#   'hide',
#   'sanctimonious',
#   'cousin',
#   'anglican',
#   'bishop',
#   'leading',
#   'campaign',
#   'writing'],
#  ['retired',
#   'auto',
#   'manufacturer',
#   'wife',
#   'take',
#   'long',
#   'planned',
#   'european',
#   'vacation',
#   'find',
#   'want',
#   'different',
#   'things',
#   'life'],
#  ['hungarian',
#   'countess',
#   'marya',
#   'zaleska',
#   'seeks',
#   'aid',
#   'noted',
#   'psychiatrist',
#   'hopes',
#   'freeing',
#   'mysterious',
#   'evil',
#   'influence'],
#  ['navy',
#   'sailor',
#   'tries',
#   'rekindle',
#   'romance',
#   'woman',
#   'loves',
#   'liberty',
#   'san',
#   'francisco'],
#  ['three',
#   'earthlings',
#   'visit',
#   'planet',
#   'mongo',
#   'thwart',
#   'evil',
#   'schemes',
#   'emperor',
#   'ming',
#   'merciless'],
#  ['wrongly',
#   'accused',
#   'prisoner',
#   'barely',
#   'survives',
#   'lynch',
#   'mob',
#   'attack',
#   'presumed',
#   'dead',
#   'vindictively',
#   'decides',
#   'frame',
#   'mob',
#   'murder'],
#  ['two',
#   'geisha',
#   'sisters',
#   'lead',
#   'hard',
#   'life',
#   'gion',
#   'district',
#   'kyoto',
#   'one',
#   'feels',
#   'obliged',
#   'support',
#   'bankrupt',
#   'businessman',
#   'sister',
#   'sets',
#   'various',
#   'schemes',
#   'get',
#   'rid'],
#  ['star',
#   'crossed',
#   'desert',
#   'romance',
#   'cloistered',
#   'woman',
#   'renegade',
#   'monk'],
#  ['movie',
#   'star',
#   'stranded',
#   'country',
#   'trifles',
#   'young',
#   'man',
#   'affections'],
#  ['amid',
#   'anarchy',
#   'china',
#   'american',
#   'mercenary',
#   'tangles',
#   'ruthless',
#   'warlord'],
#  ['small', 'boy', 'instrumental', 'famous', 'civil', 'war', 'victory'],
#  ['stage',
#   'producer',
#   'horbart',
#   'going',
#   'put',
#   'new',
#   'show',
#   'know',
#   'two',
#   'partners',
#   'lost',
#   'money',
#   'stock',
#   'market',
#   'insurance',
#   'salesman',
#   'rosmer',
#   'peck',
#   'falls',
#   'love'],
#  ['golem',
#   'giant',
#   'creature',
#   'created',
#   'clay',
#   'rabbi',
#   'comes',
#   'life',
#   'time',
#   'trouble',
#   'protect',
#   'jews',
#   'prague',
#   'persecution'],
#  ['president',
#   'andrew',
#   'jackson',
#   'friendship',
#   'innkeeper',
#   'daughter',
#   'spells',
#   'trouble'],
#  ...]

# %%
# Assign plot to the df
df['clean_plot'] = plot

# %%
df['clean_plot']
# Out:
# 0        [performing, looks, like, small, wooden, stage...
# 1        [fairy, godmother, magically, turns, cinderell...
# 2        [porter, sequential, continuity, editing, link...
# 3                   [group, astronomers, expedition, moon]
# 4        [porter, sequential, continuity, editing, link...
#                                ...
# 34143    [arianna, nineteen, years, old, still, first, ...
# 34144    [five, interlocking, tales, terror, follow, fa...
# 34145    [squad, unsuspecting, cops, goes, trapdoor, he...
# 34146    [desolate, island, suicidal, sheep, franck, me...
# 34147    [story, minibus, driver, fairytale, princesss,...
# Name: clean_plot, Length: 34148, dtype: object

# %%
df.head()
# Out:
#    imdbID                        title  year     rating runtime  \
# 0       1                   Carmencita  1894  NOT RATED   1 min
# 1     230                   Cinderella  1899        NaN   6 min
# 2     399       Jack and the Beanstalk  1902        NaN  10 min
# 3     417           A Trip to the Moon  1902       TV-G  13 min
# 4     447  Life of an American Fireman  1903  NOT RATED   6 min
#
#                        genre    released                            director  \
# 0         Documentary, Short         NaN                William K.L. Dickson
# 1               Drama, Short  1899-12-25                      Georges M�li�s
# 2             Short, Fantasy  1902-07-15  George S. Fleming, Edwin S. Porter
# 3  Short, Adventure, Fantasy  1902-10-04                      Georges M�li�s
# 4              Short, Action  1903-01-01  George S. Fleming, Edwin S. Porter
#
#                      writer                                             cast  \
# 0                       NaN                                       Carmencita
# 1  Charles Perrault (story)  Barral, Bleuette Bernon, Carmely, Jeanne d'Alcy
# 2                       NaN                                     Thomas White
# 3                       NaN          Fran�ois Lallement, Jules-Eug�ne Legris
# 4                       NaN     Vivian Vaughan, Arthur White, James H. White
#
#    ...  imdbVotes                                             poster  \
# 0  ...     1032.0  https://m.media-amazon.com/images/M/MV5BMjAzND...
# 1  ...      586.0  https://m.media-amazon.com/images/M/MV5BMTgwMD...
# 2  ...      442.0  https://m.media-amazon.com/images/M/MV5BMjAzNT...
# 3  ...    23904.0  https://m.media-amazon.com/images/M/MV5BMTQzMD...
# 4  ...     1158.0  https://m.media-amazon.com/images/M/MV5BMjAzNT...
#
#                                                 plot  \
# 0  Performing on what looks like a small wooden s...
# 1  A fairy godmother magically turns Cinderella's...
# 2  Porter's sequential continuity editing links s...
# 3  A group of astronomers go on an expedition to ...
# 4  Porter's sequential continuity editing links s...
#
#                                             fullplot language country awards  \
# 0  Performing on what looks like a small wooden s...      NaN     USA    NaN
# 1  A fairy godmother magically turns Cinderella's...      NaN  France    NaN
# 2  Porter's sequential continuity editing links s...  English     USA    NaN
# 3  A group of men travel to the moon by being sho...      NaN  France    NaN
# 4  Porter's sequential continuity editing links s...  English     USA    NaN
#
#                      lastupdated   type  \
# 0  2015-08-26 00:03:45.040000000  movie
# 1  2015-08-29 00:20:56.217000000  movie
# 2  2015-08-29 00:25:25.360000000  movie
# 3  2015-09-01 00:16:55.443000000  movie
# 4  2015-08-29 00:26:36.093000000  movie
#
#                                           clean_plot
# 0  [performing, looks, like, small, wooden, stage...
# 1  [fairy, godmother, magically, turns, cinderell...
# 2  [porter, sequential, continuity, editing, link...
# 3             [group, astronomers, expedition, moon]
# 4  [porter, sequential, continuity, editing, link...
#
# [5 rows x 22 columns]

# %%
df['genre']
# Out:
# 0               Documentary, Short
# 1                     Drama, Short
# 2                   Short, Fantasy
# 3        Short, Adventure, Fantasy
# 4                    Short, Action
#                    ...
# 34143                        Drama
# 34144                       Horror
# 34145              Fantasy, Horror
# 34146             Animation, Short
# 34147     Comedy, Fantasy, Romance
# Name: genre, Length: 34148, dtype: object

# %%
df['genre'] = df['genre'].apply(lambda x: x.split(','))
df['cast'] = df['cast'].apply(lambda x: x.split(',')[:4]) # Getting the top 4 actors
df['director'] = df['director'].apply(lambda x: x.split(',')[:1]) # Getting 1 director

# %%
df['cast'][0]
# Out:
# ['Carmencita']

# %%
def clean(sentence):
    temp = []
    for word in sentence:
        temp.append(word.lower().replace(' ', ''))
    return temp
# to clean the sentence all lower and remove all spaces

# %%
df['genre'] = [clean(x) for x in df['genre']]
df['cast'] = [clean(x) for x in df['cast']]
df['director'] = [clean(x) for x in df['director']]

# %%
df['cast'][0]
# Out:
# ['carmencita']

# %%
df['genre'][0]
# Out:
# ['documentary', 'short']

# %%
#combine all of the preproccesing into another dataframe

columns = ['clean_plot', 'genre', 'cast', 'director']
l = []

for i in range(len(df)):
    words = ''
    for col in columns:
        words += ' '.join(df[col][i]) + ' '
    l.append(words)

l
# Out:
# ['performing looks like small wooden stage wearing dress hoop skirt white high heeled pumps carmencita dance kicks twirls smile always face documentary short carmencita williamk.l.dickson ',
#  "fairy godmother magically turns cinderella rags beautiful dress pumpkin coach cinderella goes ball meets prince remember leave magic runs drama short barral bleuettebernon carmely jeanned'alcy georgesm�li�s ",
#  'porter sequential continuity editing links several shots form narrative famous fairy tale story jack magic beanstalk borrowing cinematographic methods short fantasy thomaswhite georges.fleming ',
#  'group astronomers expedition moon short adventure fantasy fran�oislallement jules-eug�nelegris georgesm�li�s ',
#  'porter sequential continuity editing links several shots form narrative firemen responding house fire leave station horse drawn pumper arrive short action vivianvaughan arthurwhite jamesh.white georges.fleming ',
#  "group bandits stage brazen train hold find determined posse hot heels short western a.c.abadie gilbertm.'bronchobilly'anderson georgebarnes justusd.barnes edwins.porter ",
#  'royal court prince presenting princess pledged marry witch suddenly appears though driven witch soon returns summons servants short adventure fantasy bleuettebernon georgesm�li�s georgesm�li�s ',
#  'using every known means transportation several savants geographic society undertake journey alps sun finishes sea short adventure fantasy georgesm�li�s georgesm�li�s ',
#  'young boy opressed mother goes outing country social welfare group dares dream land cares ordinary life fade short drama fantasy martinfuller mrs.williambechtel walteredwin etheljewett haroldm.shaw ',
#  'two travellers tormented satan inn inn eventuly experience buggy ride heavens courtesy devil takes one hell roasts short fantasy georgesm�li�s georgesm�li�s ',
#  'caring sick daughter doctor called away sickbed neighbor finds neighbor gravely ill ignores wife pleas come home care daughter taken turn worse short drama katebruce adeledegarde gladysegan roseking d.w.griffith ',
#  'frankenstein young medical student trying create perfect human instead creates misshapen monster made ill done frankenstein comforted fianc short fantasy horror maryfuller charlesogle augustusphillips j.searledawley ',
#  'cartoon figures announce via comic strip balloons move move wildly exaggerated style animation short comedy winsormccay winsormccay ',
#  'scientists world meeting discuss best way reach north pole professor maboul demonstrates innovative equipment designed short adventure sci-fi georgesm�li�s fernandealbany georgesm�li�s ',
# 2  ...      442.0  https://m.media-amazon.com/images/M/MV5BMjAzNT...
# 3  ...    23904.0  https://m.media-amazon.com/images/M/MV5BMTQzMD...
# 4  ...     1158.0  https://m.media-amazon.com/images/M/MV5BMjAzNT...
#
#                                                 plot  \
# 0  Performing on what looks like a small wooden s...
# 1  A fairy godmother magically turns Cinderella's...
# 2  Porter's sequential continuity editing links s...
# 3  A group of astronomers go on an expedition to ...
# 4  Porter's sequential continuity editing links s...
#
#                                             fullplot language country awards  \
# 0  Performing on what looks like a small wooden s...      NaN     USA    NaN
# 1  A fairy godmother magically turns Cinderella's...      NaN  France    NaN
# 2  Porter's sequential continuity editing links s...  English     USA    NaN
# 3  A group of men travel to the moon by being sho...      NaN  France    NaN
# 4  Porter's sequential continuity editing links s...  English     USA    NaN
#
#                      lastupdated   type  \
# 0  2015-08-26 00:03:45.040000000  movie
# 1  2015-08-29 00:20:56.217000000  movie
# 2  2015-08-29 00:25:25.360000000  movie
# 3  2015-09-01 00:16:55.443000000  movie
# 4  2015-08-29 00:26:36.093000000  movie
#
#                                           clean_plot
# 0  [performing, looks, like, small, wooden, stage...
# 1  [fairy, godmother, magically, turns, cinderell...
# 2  [porter, sequential, continuity, editing, link...
# 3             [group, astronomers, expedition, moon]
# 4  [porter, sequential, continuity, editing, link...
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['imdbID', 'title', 'year', 'rating', 'runtime', 'genre', 'released',
#        'director', 'writer', 'cast', 'metacritic', 'imdbRating', 'imdbVotes',
#        'poster', 'plot', 'fullplot', 'language', 'country', 'awards',
#        'lastupdated', 'type', 'clean_plot'],
#       dtype='object')

# %%
df['clean_input'] = l
df = df[['title', 'poster', 'clean_input']]
df.head() #Processed with the title with the input from genre, plot, actors and director
# Out:
#                          title  \
# 0                   Carmencita
# 1                   Cinderella
# 2       Jack and the Beanstalk
# 3           A Trip to the Moon
# 4  Life of an American Fireman
#
#                                               poster  \
# 0  https://m.media-amazon.com/images/M/MV5BMjAzND...
# 1  https://m.media-amazon.com/images/M/MV5BMTgwMD...
# 2  https://m.media-amazon.com/images/M/MV5BMjAzNT...
# 3  https://m.media-amazon.com/images/M/MV5BMTQzMD...
# 4  https://m.media-amazon.com/images/M/MV5BMjAzNT...
#
#                                          clean_input
# 0  performing looks like small wooden stage weari...
# 1  fairy godmother magically turns cinderella rag...
# 2  porter sequential continuity editing links sev...
# 3  group astronomers expedition moon short advent...
# 4  porter sequential continuity editing links sev...

# %%
df['clean_input'][0]
# Out:
# 'performing looks like small wooden stage wearing dress hoop skirt white high heeled pumps carmencita dance kicks twirls smile always face documentary short carmencita williamk.l.dickson '

# %%
# Function to insert data into Azure SQL Database
def insert_into_sql(df, server, database, username, password):
    driver = 'ODBC Driver 17 for SQL Server'
    connection_string = f"mssql+pyodbc://{username}:{password}@{server}:1433/{database}?driver={driver}"

    # Create SQLAlchemy engine
    engine = create_engine(connection_string)

    # Insert data into Azure SQL table
    df.to_sql('cleaned_data', con=engine, if_exists='replace', index=False)

# Insert data into Azure SQL
insert_into_sql(df, servername, database, serveradminlogin, serveradminpassword)
